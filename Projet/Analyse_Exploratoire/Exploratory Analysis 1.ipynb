# %% [markdown]
# # Exploratory Analysis 1

# %%
import pandas as pd
from IPython.display import HTML, display
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data_preproc.csv")

# %%
#¨pourquoi cette colonne bizarre apparait
del df["Unnamed: 0"]

# %%
#affichage au format HTML
#display(HTML(df.to_html()))

# %%
df.columns
# Out:
# Index(['id', 'net profit / total assets (ROA)',
#        'total liabilities / total assets', 'working capital / total assets',
#        'current assets / short-term liabilities',
#        '[(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365',
#        'retained earnings / total assets', 'EBIT / total assets',
#        'book value of equity / total liabilities', 'sales / total assets',
#        'equity / total assets',
#        '(gross profit + extraordinary items + financial expenses) / total assets',
#        'gross profit / short-term liabilities',
#        '(gross profit + depreciation) / sales',
#        '(gross profit + interest) / total assets',
#        '(total liabilities * 365) / (gross profit + depreciation)',
#        '(gross profit + depreciation) / total liabilities',
#        'total assets / total liabilities', 'gross profit / total assets',
#        'gross profit / sales', '(inventory * 365) / sales',
# ...

# %%
features = df.drop(labels = ["id","bankrupt"], axis = 1)
features
# Out:
#       net profit / total assets (ROA)  total liabilities / total assets  \
# 0                            0.174190                          0.412990
# 1                            0.024526                          0.432360
# 2                            0.188290                          0.415040
# 3                            0.115030                          0.036659
# 4                            0.009832                          0.670660
# ...                               ...                               ...
# 4880                         0.003603                          0.824060
# 4881                         0.180780                          1.014800
# 4882                        -0.019241                          0.698810
# 4883                         0.062089                          0.768410
# 4884                        -0.001775                          0.947800
#
#       working capital / total assets  current assets / short-term liabilities  \
# ...

# %%
target = pd.DataFrame(df["bankrupt"])
target
# Out:
#       bankrupt
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 4880         1
# 4881         1
# 4882         1
# 4883         1
# 4884         1
#
# [4885 rows x 1 columns]

# %%
# Description statistiques des features
display(HTML(features.describe().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>net profit / total assets (ROA)</th>
#       <th>total liabilities / total assets</th>
#       <th>working capital / total assets</th>
#       <th>current assets / short-term liabilities</th>
#       <th>[(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365</th>
#       <th>retained earnings / total assets</th>
#       <th>EBIT / total assets</th>
#       <th>book value of equity / total liabilities</th>
#       <th>sales / total assets</th>
#       <th>equity / total assets</th>
#       <th>(gross profit + extraordinary items + financial expenses) / total assets</th>
#       <th>gross profit / short-term liabilities</th>
#       <th>(gross profit + depreciation) / sales</th>
#       <th>(gross profit + interest) / total assets</th>
#       <th>(total liabilities * 365) / (gross profit + depreciation)</th>
# ...

# %% [markdown]
# ## Conclusion description

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## 1. ROA

# %%
# Boxplot ROA

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('ROA', fontsize=20)

sns.boxplot(y ='net profit / total assets (ROA)', data = features)

plt.ylabel('net profit / total assets (ROA)')
# Out:
# Text(0, 0.5, 'net profit / total assets (ROA)')

# %%
# Boxplot ROA without outliers

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('ROA', fontsize=20)

sns.boxplot(y ='net profit / total assets (ROA)', data = features,showfliers = False)

plt.ylabel('net profit / total assets (ROA)')
# Out:
# Text(0, 0.5, 'net profit / total assets (ROA)')

# %% [markdown]
# ### With the target

# %%
# Boxplot ROA

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('ROA and bankrupt', fontsize=20)

sns.boxplot(x = "bankrupt", y ='net profit / total assets (ROA)', data = df)

plt.ylabel('net profit / total assets (ROA)')
# Out:
# Text(0, 0.5, 'net profit / total assets (ROA)')

# %%
# Boxplot ROA

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('ROA and bankrupt', fontsize=20)

sns.boxplot(x = "bankrupt", y ='net profit / total assets (ROA)', data = df, showfliers = False)

plt.ylabel('net profit / total assets (ROA)')
# Out:
# Text(0, 0.5, 'net profit / total assets (ROA)')

# %% [markdown]
# On remarque un léger impact, le ROA des entreprises qui sont en banque route, ont un ROA inférieur

# %% [markdown]
# ## 2. Debt Ratio

# %%
# Boxplot Debt Ratio

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Debt Ratio', fontsize=20)

sns.boxplot(y ='total liabilities / total assets', data = features, showfliers = False)

plt.ylabel('total liabilities / total assets')
# Out:
# Text(0, 0.5, 'total liabilities / total assets')

# %% [markdown]
# ### With target

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Debt Ratio', fontsize=20)

sns.boxplot(x="bankrupt", y ='total liabilities / total assets', data = df, showfliers = False)

plt.ylabel('total liabilities / total assets')
# Out:
# Text(0, 0.5, 'total liabilities / total assets')

# %% [markdown]
# debt ratio plus élevé pour les entreprises e bankrupt

# %% [markdown]
# ## 3. Working Capital to Assets ratio

# %%
# Boxplot Working Capital to Assets ratio

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Working Capital to Assets ratio', fontsize=20)

sns.boxplot(y ='working capital / total assets', data = features, showfliers = False)

plt.ylabel('working capital / total assets')
# Out:
# Text(0, 0.5, 'working capital / total assets')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Working Capital to Assets ratio', fontsize=20)

sns.boxplot(x = "bankrupt", y ='working capital / total assets', data = df, showfliers = False)

plt.ylabel('working capital / total assets')
# Out:
# Text(0, 0.5, 'working capital / total assets')

# %% [markdown]
# ## 4.Current Ratio

# %%
# Boxplot Current ratio

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Current Ratio', fontsize=20)

sns.boxplot(y ='current assets / short-term liabilities', data = features, showfliers = False)

plt.ylabel('current assets / short-term liabilities')
# Out:
# Text(0, 0.5, 'current assets / short-term liabilities')

# %%
# Boxplot Current to Assets ratio

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Current Ratio and bankrupt', fontsize=20)

sns.boxplot(x = "bankrupt", y ='current assets / short-term liabilities', data = df, showfliers = False)

plt.ylabel('current assets / short-term liabilities')
# Out:
# Text(0, 0.5, 'current assets / short-term liabilities')

# %% [markdown]
# ## 5.[(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365

# %%
# Boxplot Current ratio

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('var5', fontsize=20)

sns.boxplot(y ='[(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365', data = features, showfliers = False)

plt.ylabel('var5')
# Out:
# Text(0, 0.5, 'var5')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('var5', fontsize=20)

sns.boxplot(x = "bankrupt", y ='[(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365', data = df, showfliers = False)

plt.ylabel('var5')
# Out:
# Text(0, 0.5, 'var5')

# %% [markdown]
# ## 6. Retained Earnings to Total Asset

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Retained Earnings to Total Asset', fontsize=20)

sns.boxplot(y ='retained earnings / total assets', data = features, showfliers = False)

plt.ylabel('retained earnings / total asset')
# Out:
# Text(0, 0.5, 'retained earnings / total asset')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Retained Earnings to Total Asset', fontsize=20)

sns.boxplot(x = "bankrupt", y ='retained earnings / total assets', data = df, showfliers = False)

plt.ylabel('retained earnings / total asset')
# Out:
# Text(0, 0.5, 'retained earnings / total asset')

# %% [markdown]
# ## 7.EBIT

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('EBIT', fontsize=20)

sns.boxplot(y ='EBIT / total assets', data = features, showfliers = False)

plt.ylabel('EBIT / total assets')
# Out:
# Text(0, 0.5, 'EBIT / total assets')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('EBIT', fontsize=20)

sns.boxplot(x = "bankrupt", y ='EBIT / total assets', data = df, showfliers = False)

plt.ylabel('EBIT / total assets')
# Out:
# Text(0, 0.5, 'EBIT / total assets')

# %% [markdown]
# ### 8.Book Value of Total Liabilities

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Book Value of Total Liabilities', fontsize=20)

sns.boxplot(y ='book value of equity / total liabilities', data = features, showfliers = False)

plt.ylabel('book value of equity / total liabilities')
# Out:
# Text(0, 0.5, 'book value of equity / total liabilities')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Book Value of Total Liabilities', fontsize=20)

sns.boxplot(x = "bankrupt", y ='book value of equity / total liabilities', data = df, showfliers = False)

plt.ylabel('book value of equity / total liabilities')
# Out:
# Text(0, 0.5, 'book value of equity / total liabilities')

# %% [markdown]
# ## 9.Sales Ratio

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Sales Ratio', fontsize=20)

sns.boxplot(y ='sales / total assets', data = features, showfliers = False)

plt.ylabel('sales / total assets')
# Out:
# Text(0, 0.5, 'sales / total assets')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Sales Ratio', fontsize=20)

sns.boxplot(x = "bankrupt", y ='sales / total assets', data = df, showfliers = False)

plt.ylabel('sales / total assets')
# Out:
# Text(0, 0.5, 'sales / total assets')

# %% [markdown]
# ## 10. Equity

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Equity Ratio', fontsize=20)

sns.boxplot(y ='equity / total assets', data = features, showfliers = False)

plt.ylabel('equity / total assets')
# Out:
# Text(0, 0.5, 'equity / total assets')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Equity Ratio', fontsize=20)

sns.boxplot(x="bankrupt", y ='equity / total assets', data = df, showfliers = False)

plt.ylabel('equity / total assets')
# Out:
# Text(0, 0.5, 'equity / total assets')

# %% [markdown]
# ## 11.(gross profit + extraordinary items + financial expenses) / total assets

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Incomes', fontsize=20)

sns.boxplot(y ='(gross profit + extraordinary items + financial expenses) / total assets', data = features, showfliers = False)

plt.ylabel('(GP + extra items + finl expenses) / total assets')
# Out:
# Text(0, 0.5, '(GP + extra items + finl expenses) / total assets')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Incomes', fontsize=20)

sns.boxplot(x = "bankrupt",y ='(gross profit + extraordinary items + financial expenses) / total assets', data = df, showfliers = False)

plt.ylabel('(GP + extra items + finl expenses) / total assets')
# Out:
# Text(0, 0.5, '(GP + extra items + finl expenses) / total assets')

# %% [markdown]
# ## 12. Gros Profits liabilities

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Gross profits liabilities', fontsize=20)

sns.boxplot(y ='gross profit / short-term liabilities', data = features, showfliers = False)

plt.ylabel('gross profit / short-term liabilities')
# Out:
# Text(0, 0.5, 'gross profit / short-term liabilities')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Gross profits liabilities', fontsize=20)

sns.boxplot(x = "bankrupt", y ='gross profit / short-term liabilities', data = df, showfliers = False)

plt.ylabel('gross profit / short-term liabilities')
# Out:
# Text(0, 0.5, 'gross profit / short-term liabilities')

# %% [markdown]
# ## 13.gross profit depreciation

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Gross profits depreciation', fontsize=20)

sns.boxplot(y ='(gross profit + depreciation) / sales', data = features, showfliers = False)

plt.ylabel('(gross profit + depreciation) / sales')
# Out:
# Text(0, 0.5, '(gross profit + depreciation) / sales')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Gross profits depreciation', fontsize=20)

sns.boxplot(x = "bankrupt", y ='(gross profit + depreciation) / sales', data = df, showfliers = False)

plt.ylabel('(gross profit + depreciation) / sales')
# Out:
# Text(0, 0.5, '(gross profit + depreciation) / sales')

# %% [markdown]
# ## 14.gross profit interest

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Gross profits interest', fontsize=20)

sns.boxplot(y ='(gross profit + interest) / total assets', data = features, showfliers = False)

plt.ylabel('(gross profit + interest) / total assets')
# Out:
# Text(0, 0.5, '(gross profit + interest) / total assets')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Gross profits interest', fontsize=20)

sns.boxplot(x="bankrupt",y ='(gross profit + interest) / total assets', data = df, showfliers = False)

plt.ylabel('(gross profit + interest) / total assets')
# Out:
# Text(0, 0.5, '(gross profit + interest) / total assets')

# %% [markdown]
# ## 15. (total liabilities * 365) / (gross profit + depreciation)

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Gross profits interest', fontsize=20)

sns.boxplot(y ='(total liabilities * 365) / (gross profit + depreciation)', data = features, showfliers = False)

plt.ylabel('(total liabilities * 365) / (gross profit + depreciation)')
# Out:
# Text(0, 0.5, '(total liabilities * 365) / (gross profit + depreciation)')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Gross profits interest', fontsize=20)

sns.boxplot(x = "bankrupt", y ='(total liabilities * 365) / (gross profit + depreciation)', data = df, showfliers = False)

plt.ylabel('(total liabilities * 365) / (gross profit + depreciation)')
# Out:
# Text(0, 0.5, '(total liabilities * 365) / (gross profit + depreciation)')

# %% [markdown]
# ## 16. (gross profit + depreciation) / total liabilities

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('(gross profit + depreciation) / total liabilities', fontsize=20)

sns.boxplot(y ='(gross profit + depreciation) / total liabilities', data = features, showfliers = False)

plt.ylabel('(gross profit + depreciation) / total liabilities')
# Out:
# Text(0, 0.5, '(gross profit + depreciation) / total liabilities')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('(gross profit + depreciation) / total liabilities', fontsize=20)

sns.boxplot(x = "bankrupt", y ='(gross profit + depreciation) / total liabilities', data = df, showfliers = False)

plt.ylabel('(gross profit + depreciation) / total liabilities')
# Out:
# Text(0, 0.5, '(gross profit + depreciation) / total liabilities')

# %% [markdown]
# ## 17.total assets / total liabilities (c'est l'inverse du 2.)

# %% [markdown]
# ## 18.gross profit / total assets

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('gross profit and total assets', fontsize=20)

sns.boxplot(y ='gross profit / total assets', data = features, showfliers = False)

plt.ylabel('gross profit / total assets')
# Out:
# Text(0, 0.5, 'gross profit / total assets')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('gross profit and total assets', fontsize=20)

sns.boxplot(x = "bankrupt", y ='gross profit / total assets', data = df, showfliers = False)

plt.ylabel('gross profit / total assets')
# Out:
# Text(0, 0.5, 'gross profit / total assets')

# %% [markdown]
# ## 19. gross profit / sales

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('gross profit and sales', fontsize=20)

sns.boxplot(y ='gross profit / sales', data = features, showfliers = False)

plt.ylabel('gross profit / sales')
# Out:
# Text(0, 0.5, 'gross profit / sales')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('gross profit and sales', fontsize=20)

sns.boxplot(x = "bankrupt",y ='gross profit / sales', data = df, showfliers = False)

plt.ylabel('gross profit / sales')
# Out:
# Text(0, 0.5, 'gross profit / sales')

# %% [markdown]
# ## 20.Day Sales in inventory Ratio

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Day Sales in inventory Ratio', fontsize=20)

sns.boxplot(y ='(inventory * 365) / sales', data = features, showfliers = False)

plt.ylabel('g(inventory * 365) / sales')
# Out:
# Text(0, 0.5, 'g(inventory * 365) / sales')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Day Sales in inventory Ratio', fontsize=20)

sns.boxplot(x = "bankrupt", y ='(inventory * 365) / sales', data = df, showfliers = False)

plt.ylabel('g(inventory * 365) / sales')
# Out:
# Text(0, 0.5, 'g(inventory * 365) / sales')

# %% [markdown]
# ## 21. Comparing previous and actual years sales

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('previous and actual years sales', fontsize=20)

sns.boxplot(y ='sales (n) / sales (n-1)', data = features, showfliers = False)

plt.ylabel('sales (n) / sales (n-1)')
# Out:
# Text(0, 0.5, 'sales (n) / sales (n-1)')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('previous and actual years sales', fontsize=20)

sns.boxplot(x = "bankrupt", y ='sales (n) / sales (n-1)', data = df, showfliers = False)

plt.ylabel('sales (n) / sales (n-1)')
# Out:
# Text(0, 0.5, 'sales (n) / sales (n-1)')

# %% [markdown]
# ## 22. Return on operating assets OROA

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('OROA', fontsize=20)

sns.boxplot(y ='profit on operating activities / total assets', data = features, showfliers = False)

plt.ylabel('profit on operating activities / total assets')
# Out:
# Text(0, 0.5, 'profit on operating activities / total assets')

# %%
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('OROA', fontsize=20)

sns.boxplot(x = "bankrupt", y ='profit on operating activities / total assets', data = df, showfliers = False)

plt.ylabel('profit on operating activities / total assets')
# Out:
# Text(0, 0.5, 'profit on operating activities / total assets')

# %% [markdown]
# ## 23. Net income

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Net income', fontsize=20)

sns.boxplot(y ='net profit / sales', data = features, showfliers = False)

plt.ylabel('net profit / sales')
# Out:
# Text(0, 0.5, 'net profit / sales')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Net income', fontsize=20)

sns.boxplot(x="bankrupt",y ='net profit / sales', data = df, showfliers = False)

plt.ylabel('net profit / sales')
# Out:
# Text(0, 0.5, 'net profit / sales')

# %% [markdown]
# ## 24. ROA on the last 3 years

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('ROA on the last 3 years', fontsize=20)

sns.boxplot(y ='gross profit (in 3 years) / total assets', data = features, showfliers = False)

plt.ylabel('gross profit (in 3 years) / total assets')
# Out:
# Text(0, 0.5, 'gross profit (in 3 years) / total assets')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('ROA on the last 3 years', fontsize=20)

sns.boxplot(x="bankrupt",y ='gross profit (in 3 years) / total assets', data = df, showfliers = False)

plt.ylabel('gross profit (in 3 years) / total assets')
# Out:
# Text(0, 0.5, 'gross profit (in 3 years) / total assets')

# %% [markdown]
# ## 25. Shareholder equity ratio

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Shareholder equity ratio', fontsize=20)

sns.boxplot(y ='(equity - share capital) / total assets', data = features, showfliers = False)

plt.ylabel('(equity - share capital) / total assets')
# Out:
# Text(0, 0.5, '(equity - share capital) / total assets')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Shareholder equity ratio', fontsize=20)

sns.boxplot(x = "bankrupt", y ='(equity - share capital) / total assets', data = df, showfliers = False)

plt.ylabel('(equity - share capital) / total assets')
# Out:
# Text(0, 0.5, '(equity - share capital) / total assets')

# %% [markdown]
# ## 26. Net Solvency ratio

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Net solbency Ratio', fontsize=20)

sns.boxplot(y ='(net profit + depreciation) / total liabilities', data = features, showfliers = False)

plt.ylabel('(net profit + depreciation) / total liabilities')
# Out:
# Text(0, 0.5, '(net profit + depreciation) / total liabilities')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Net solbency Ratio', fontsize=20)

sns.boxplot(x="bankrupt", y ='(net profit + depreciation) / total liabilities', data = df, showfliers = False)

plt.ylabel('(net profit + depreciation) / total liabilities')
# Out:
# Text(0, 0.5, '(net profit + depreciation) / total liabilities')

# %% [markdown]
# ## 27. profit on operating activities / financial expenses

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))


sns.boxplot(y ='profit on operating activities / financial expenses', data = features, showfliers = False)

plt.ylabel('profit on operating activities / financial expenses')
# Out:
# Text(0, 0.5, 'profit on operating activities / financial expenses')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))


sns.boxplot(x="bankrupt", y ='profit on operating activities / financial expenses', data = df, showfliers = False)

plt.ylabel('profit on operating activities / financial expenses')
# Out:
# Text(0, 0.5, 'profit on operating activities / financial expenses')

# %% [markdown]
# ## 28. working capital / fixed assets

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))


sns.boxplot(y ='working capital / fixed assets', data = features, showfliers = False)

plt.ylabel('working capital / fixed assets')
# Out:
# Text(0, 0.5, 'working capital / fixed assets')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))


sns.boxplot(x = "bankrupt", y ='working capital / fixed assets', data = df, showfliers = False)

plt.ylabel('working capital / fixed assets')
# Out:
# Text(0, 0.5, 'working capital / fixed assets')

# %% [markdown]
# ## 29. logarithm of total assets

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))


sns.boxplot(y ='logarithm of total assets', data = features, showfliers = False)

plt.ylabel('logarithm of total assets')
# Out:
# Text(0, 0.5, 'logarithm of total assets')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))


sns.boxplot(x = "bankrupt", y ='logarithm of total assets', data = df, showfliers = False)

plt.ylabel('logarithm of total assets')
# Out:
# Text(0, 0.5, 'logarithm of total assets')

# %% [markdown]
# ## 30. (total liabilities - cash) / sales

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))


sns.boxplot(y ='(total liabilities - cash) / sales', data = features, showfliers = False)

plt.ylabel('(total liabilities - cash) / sales')
# Out:
# Text(0, 0.5, '(total liabilities - cash) / sales')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))


sns.boxplot(x = "bankrupt" , y ='(total liabilities - cash) / sales', data = df, showfliers = False)

plt.ylabel('(total liabilities - cash) / sales')
# Out:
# Text(0, 0.5, '(total liabilities - cash) / sales')

# %% [markdown]
# ## 31. (gross profit + interest) / sales

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))


sns.boxplot(y ='(gross profit + interest) / sales', data = features, showfliers = False)

plt.ylabel('(gross profit + interest) / sales')
# Out:
# Text(0, 0.5, '(gross profit + interest) / sales')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))


sns.boxplot(x = "bankrupt" ,y ='(gross profit + interest) / sales', data = df, showfliers = False)

plt.ylabel('(gross profit + interest) / sales')
# Out:
# Text(0, 0.5, '(gross profit + interest) / sales')

# %% [markdown]
# ## 32. (current liabilities * 365) / cost of products sold

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))


sns.boxplot(y ='(current liabilities * 365) / cost of products sold', data = features, showfliers = False)

plt.ylabel('(current liabilities * 365) / cost of products sold')
# Out:
# Text(0, 0.5, '(current liabilities * 365) / cost of products sold')

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))


sns.boxplot(x = "bankrupt", y ='(current liabilities * 365) / cost of products sold', data = df, showfliers = False)

plt.ylabel('(current liabilities * 365) / cost of products sold')
# Out:
# Text(0, 0.5, '(current liabilities * 365) / cost of products sold')
