# %% [markdown]
# # Library

# %%
import pandas as pd
from IPython.display import HTML, display
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Multivariate Analysis

# %%
df = pd.read_csv("data_without_correlation.csv")
df
# Out:
#       net profit / total assets  current assets / short-term liabilities  \
# 0                      0.174190                                  1.34800
# 1                      0.024526                                  1.78330
# 2                      0.188290                                  1.92790
# 3                      0.115030                                112.63000
# 4                      0.009832                                  1.23930
# ...                         ...                                      ...
# 4880                   0.003603                                  0.89208
# 4881                   0.180780                                  0.86624
# 4882                  -0.019241                                  1.25360
# 4883                   0.062089                                  0.64101
# 4884                  -0.001775                                  1.00450
#
# ...

# %%
feature = df.drop("bankrupt", axis = 1)
feature
# Out:
#       net profit / total assets  current assets / short-term liabilities  \
# 0                      0.174190                                  1.34800
# 1                      0.024526                                  1.78330
# 2                      0.188290                                  1.92790
# 3                      0.115030                                112.63000
# 4                      0.009832                                  1.23930
# ...                         ...                                      ...
# 4880                   0.003603                                  0.89208
# 4881                   0.180780                                  0.86624
# 4882                  -0.019241                                  1.25360
# 4883                   0.062089                                  0.64101
# 4884                  -0.001775                                  1.00450
#
# ...

# %% [markdown]
# ## Rappel Analyse Target

# %%
for col in df:
    plt.figure()
    sns.distplot(df[df['bankrupt']==0][col], label = 'bankrupt')
    sns.distplot(df[df['bankrupt']==1][col], label = '0')
    plt.legend()
