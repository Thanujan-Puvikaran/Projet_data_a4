# %% [markdown]
# # Library

# %%
import pandas as pd
from IPython.display import HTML, display
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

# %% [markdown]
# # Multivariate analysis

# %%
df = pd.read_csv("../Analyse_Exploratoire/data_univariate.csv")

# %%
display(HTML(df.to_html()))

# %%
# Correlation Matrix
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams.update({'font.size': 15})
fig, ax = plt.subplots(1, 1, figsize=(20,15))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, ax=ax, cmap=plt.cm.Greens)
plt.show()

# %% [markdown]
# # Drugs

# %%
# Looking at the drugs consumption volumetry
drugs = pd.DataFrame(df.drop(["Age","Gender",'Education',"Nscore","Escore","Oscore","Ascore","Cscore","Impulsive","SS","Addiction"],axis = 1).sum()).reset_index()
drugs
# Out:
#         index     0
# 0      Amphet   679
# 1        Amyl   370
# 2      Benzos   769
# 3    Cannabis  1265
# 4        Coke   687
# 5       Crack   191
# 6     Ecstasy   751
# 7      Heroin   212
# 8    Ketamine   350
# 9      Legalh   762
# 10        LSD   557
# 11       Meth   417
# 12  Mushrooms   694
# 13        VSA   230

# %%
# Drugs Histogram
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 18
plt.figure(figsize=(15, 7))

plt.title('Drugs Histogram', fontsize=20)

sns.barplot(x = 'index', y = 0, data = drugs)

plt.xticks(rotation=90)

plt.xlabel('Drugs')
plt.ylabel('Volumetry')
plt.savefig('../../image/DrugHistogram.png',bbox_inches='tight')

# %%
drugs.set_index("index", inplace = True)
drugs["index"] = drugs.index
drugs
# Out:
#               0      index
# index
# Amphet      679     Amphet
# Amyl        370       Amyl
# Benzos      769     Benzos
# Cannabis   1265   Cannabis
# Coke        687       Coke
# Crack       191      Crack
# Ecstasy     751    Ecstasy
# Heroin      212     Heroin
# Ketamine    350   Ketamine
# Legalh      762     Legalh
# LSD         557        LSD
# Meth        417       Meth
# Mushrooms   694  Mushrooms
# VSA         230        VSA

# %%
fig = px.treemap(drugs, path=["index"], values=0, height=700,
                 title=0, color_discrete_sequence = px.colors.qualitative.Dark2)
fig.data[0].textinfo = 'label+text+value'
fig.show()

# %% [markdown]
# ### NbDrugs

# %%
# Looking at the total volumetry
df["nbDrug"] = df[['Amphet', 'Amyl',
       'Benzos', 'Cannabis', 'Coke', 'Crack', 'Ecstasy',
       'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms', 'VSA']].sum(axis = 1)

# %%
# Boxplot nbDrug vs Target

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('nbDrug and Addiction', fontsize=20)

sns.boxplot(x = "Addiction", y ='nbDrug', data = df)

plt.ylabel('NbDrug')
plt.savefig('../../image/nbDrug_vs_Target.png',bbox_inches='tight')
# Out:
# Text(0, 0.5, 'NbDrug')

# %% [markdown]
# The number of drugs consumed don't seem to have an impact on group 1 and group 2 diferenciation. But define well the diference betwenn 0 and 1 + 2

# %% [markdown]
# ## Scores

# %% [markdown]
# Looking at the relation between the drugs and each scores

# %% [markdown]
# ### Nscore

# %%
score = pd.DataFrame()
score["Amphet"] = df[df["Amphet"]==1]["Nscore"]
score["Amyl"] = df[df["Amyl"]==1]["Nscore"]
score["Benzos"] = df[df["Benzos"]==1]["Nscore"]
score["Cannabis"] = df[df["Cannabis"]==1]["Nscore"]
score["Coke"] = df[df["Coke"]==1]["Nscore"]
score["Ecstasy"] = df[df["Ecstasy"]==1]["Nscore"]
score["Heroin"] = df[df["Heroin"]==1]["Nscore"]
score["Ketamine"] = df[df["Ketamine"]==1]["Nscore"]
score["Legalh"] = df[df["Legalh"]==1]["Nscore"]
score["LSD"] = df[df["LSD"]==1]["Nscore"]
score["Meth"]  = df[df["Meth"]==1]["Nscore"]
score["Mushrooms"] = df[df["Mushrooms"]==1]["Nscore"]
#score["Nicotine"] = df[df["Nicotine"]==1]["Nscore"]
score["VSA"] = df[df["VSA"]==1]["Nscore"]
score["Crack"] = df[df["Crack"]==1]["Nscore"]

# %%
# Boxplot NScore vs who takes Drugs

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Nscore and Drugs', fontsize=20)

ax = sns.boxplot(data=score,orient="h", palette="Set2")

plt.ylabel('Nscore')
plt.savefig('../../image/NScore_drugs.png',bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Nscore')

# %% [markdown]
# Looking at the fist analysis of Nscore and the target we get that level of Addiction 2 was negative, quite similar but more around score 0 we get the level 0 and level 1 was bigger than both and positive.

# %% [markdown]
# ### Oscore

# %%
score = pd.DataFrame()
score["Amphet"] = df[df["Amphet"]==1]["Oscore"]
score["Amyl"] = df[df["Amyl"]==1]["Oscore"]
score["Benzos"] = df[df["Benzos"]==1]["Oscore"]
score["Cannabis"] = df[df["Cannabis"]==1]["Oscore"]
score["Coke"] = df[df["Coke"]==1]["Oscore"]
score["Ecstasy"] = df[df["Ecstasy"]==1]["Oscore"]
score["Heroin"] = df[df["Heroin"]==1]["Oscore"]
score["Ketamine"] = df[df["Ketamine"]==1]["Oscore"]
score["Legalh"] = df[df["Legalh"]==1]["Oscore"]
score["LSD"] = df[df["LSD"]==1]["Oscore"]
score["Meth"]  = df[df["Meth"]==1]["Oscore"]
score["Mushrooms"] = df[df["Mushrooms"]==1]["Oscore"]
#score["Nicotine"] = df[df["Nicotine"]==1]["Oscore"]
score["VSA"] = df[df["VSA"]==1]["Oscore"]
score["Crack"] = df[df["Crack"]==1]["Oscore"]

# %%
# Boxplot OScore vs who takes Drugs

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Oscore and Drugs', fontsize=20)

ax = sns.boxplot(data=score,orient="h", palette="Set2")

plt.ylabel('Oscore')
plt.savefig('../../image/Oscore_drugs.png',bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Oscore')

# %% [markdown]
# Level 2 was bigger and all drugs seems to get the similar Oscore when consumed

# %% [markdown]
# ### Escore

# %%
score = pd.DataFrame()
score["Amphet"] = df[df["Amphet"]==1]["Escore"]
score["Amyl"] = df[df["Amyl"]==1]["Escore"]
score["Benzos"] = df[df["Benzos"]==1]["Escore"]
score["Cannabis"] = df[df["Cannabis"]==1]["Escore"]
score["Coke"] = df[df["Coke"]==1]["Escore"]
score["Ecstasy"] = df[df["Ecstasy"]==1]["Escore"]
score["Heroin"] = df[df["Heroin"]==1]["Escore"]
score["Ketamine"] = df[df["Ketamine"]==1]["Escore"]
score["Legalh"] = df[df["Legalh"]==1]["Escore"]
score["LSD"] = df[df["LSD"]==1]["Escore"]
score["Meth"]  = df[df["Meth"]==1]["Escore"]
score["Mushrooms"] = df[df["Mushrooms"]==1]["Escore"]
#score["Nicotine"] = df[df["Nicotine"]==1]["Escore"]
score["VSA"] = df[df["VSA"]==1]["Escore"]
score["Crack"] = df[df["Crack"]==1]["Escore"]

# %%
# Boxplot OScore vs who takes Drugs

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Escore and Drugs', fontsize=20)

ax = sns.boxplot(data=score,orient="h", palette="Set2")

plt.ylabel('Escore')
plt.savefig('../../image/Escore_drugs.png',bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Escore')

# %% [markdown]
# - First Analysis: Level 2 positive Level 0 0 and Level 1 negative
# - Heroin,Meth, Benzos get negative and was more likely of level 1 after clustering
# - Amyl is positive and get a level 2
# - Escore seems to have a big impact on level 1 or level 2 decision

# %% [markdown]
# ## Ascore

# %%
score = pd.DataFrame()
score["Amphet"] = df[df["Amphet"]==1]["Ascore"]
score["Amyl"] = df[df["Amyl"]==1]["Ascore"]
score["Benzos"] = df[df["Benzos"]==1]["Ascore"]
score["Cannabis"] = df[df["Cannabis"]==1]["Ascore"]
score["Coke"] = df[df["Coke"]==1]["Ascore"]
score["Ecstasy"] = df[df["Ecstasy"]==1]["Ascore"]
score["Heroin"] = df[df["Heroin"]==1]["Ascore"]
score["Ketamine"] = df[df["Ketamine"]==1]["Ascore"]
score["Legalh"] = df[df["Legalh"]==1]["Ascore"]
score["LSD"] = df[df["LSD"]==1]["Ascore"]
score["Meth"]  = df[df["Meth"]==1]["Ascore"]
score["Mushrooms"] = df[df["Mushrooms"]==1]["Ascore"]
#score["Nicotine"] = df[df["Nicotine"]==1]["Ascore"]
score["VSA"] = df[df["VSA"]==1]["Ascore"]
score["Crack"] = df[df["Crack"]==1]["Ascore"]

# %%
# Boxplot OScore vs who takes Drugs

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Ascore and Drugs', fontsize=20)

ax = sns.boxplot(data=score,orient="h", palette="Set2")

plt.ylabel('Ascore')
plt.savefig('../../image/Ascore_drugs.png',bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Ascore')

# %% [markdown]
# - Level 0 and 2 was both positive
# - Level 1 was negative
# - Here Heroin, Meth, VSA, Crack are significantly negative and all of them was mostly level 1

# %% [markdown]
# ## CScore

# %%
score = pd.DataFrame()
score["Amphet"] = df[df["Amphet"]==1]["Cscore"]
score["Amyl"] = df[df["Amyl"]==1]["Cscore"]
score["Benzos"] = df[df["Benzos"]==1]["Cscore"]
score["Cannabis"] = df[df["Cannabis"]==1]["Cscore"]
score["Coke"] = df[df["Coke"]==1]["Cscore"]
score["Ecstasy"] = df[df["Ecstasy"]==1]["Cscore"]
score["Heroin"] = df[df["Heroin"]==1]["Cscore"]
score["Ketamine"] = df[df["Ketamine"]==1]["Cscore"]
score["Legalh"] = df[df["Legalh"]==1]["Cscore"]
score["LSD"] = df[df["LSD"]==1]["Cscore"]
score["Meth"]  = df[df["Meth"]==1]["Cscore"]
score["Mushrooms"] = df[df["Mushrooms"]==1]["Cscore"]
#score["Nicotine"] = df[df["Nicotine"]==1]["Cscore"]
score["VSA"] = df[df["VSA"]==1]["Cscore"]
score["Crack"] = df[df["Crack"]==1]["Cscore"]

# %%
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Cscore and Drugs', fontsize=20)

ax = sns.boxplot(data=score,orient="h", palette="Set2")

plt.ylabel('Cscore')
plt.savefig('../../image/Cscore_drugs.png',bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Cscore')

# %% [markdown]
# - Level 0 was positive
# - Level 2 was near 0 but still positive
# - Level 1 was negative
# - All Drugs are negative

# %% [markdown]
# ## Impulsive

# %%
score = pd.DataFrame()
score["Amphet"] = df[df["Amphet"]==1]["Impulsive"]
score["Amyl"] = df[df["Amyl"]==1]["Impulsive"]
score["Benzos"] = df[df["Benzos"]==1]["Impulsive"]
score["Cannabis"] = df[df["Cannabis"]==1]["Impulsive"]
score["Coke"] = df[df["Coke"]==1]["Impulsive"]
score["Ecstasy"] = df[df["Ecstasy"]==1]["Impulsive"]
score["Heroin"] = df[df["Heroin"]==1]["Impulsive"]
score["Ketamine"] = df[df["Ketamine"]==1]["Impulsive"]
score["Legalh"] = df[df["Legalh"]==1]["Impulsive"]
score["LSD"] = df[df["LSD"]==1]["Impulsive"]
score["Meth"]  = df[df["Meth"]==1]["Impulsive"]
score["Mushrooms"] = df[df["Mushrooms"]==1]["Impulsive"]
#score["Nicotine"] = df[df["Nicotine"]==1]["Impulsive"]
score["VSA"] = df[df["VSA"]==1]["Impulsive"]
score["Crack"] = df[df["Crack"]==1]["Impulsive"]

# %%
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('Impulsive and Drugs', fontsize=20)

ax = sns.boxplot(data=score,orient="h", palette="Set2")

plt.ylabel('Impulsive')
plt.savefig('../../image/Impulsive_drugs.png',bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Impulsive')

# %% [markdown]
# ## SS

# %%
score = pd.DataFrame()
score["Amphet"] = df[df["Amphet"]==1]["SS"]
score["Amyl"] = df[df["Amyl"]==1]["SS"]
score["Benzos"] = df[df["Benzos"]==1]["SS"]
score["Cannabis"] = df[df["Cannabis"]==1]["SS"]
score["Coke"] = df[df["Coke"]==1]["SS"]
score["Ecstasy"] = df[df["Ecstasy"]==1]["SS"]
score["Heroin"] = df[df["Heroin"]==1]["SS"]
score["Ketamine"] = df[df["Ketamine"]==1]["SS"]
score["Legalh"] = df[df["Legalh"]==1]["SS"]
score["LSD"] = df[df["LSD"]==1]["SS"]
score["Meth"]  = df[df["Meth"]==1]["SS"]
score["Mushrooms"] = df[df["Mushrooms"]==1]["SS"]
#score["Nicotine"] = df[df["Nicotine"]==1]["SS"]
score["VSA"] = df[df["VSA"]==1]["SS"]
score["Crack"] = df[df["Crack"]==1]["SS"]

# %%
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['font.size'] = 26
plt.figure(figsize=(10, 7))

plt.title('SS and Drugs', fontsize=20)

ax = sns.boxplot(data=score,orient="h", palette="Set2")

plt.ylabel('SS')
plt.savefig('../../image/SS_drugs.png',bbox_inches='tight')
# Out:
# Text(0, 0.5, 'SS')

# %% [markdown]
# # Conclusion

# %% [markdown]
# Level 1 and 2 are diferentiated by the type of drug consumed wich will have diferent impact on the person. Type 1 people will be affected more thant type 1 people

# %%
df.drop(columns = ["nbDrug"], inplace = True, axis=1)
df.loc[df["Addiction"] == 0, "Addiction"] = "No Addiction"
df.loc[df["Addiction"] == 1, "Addiction"] = "Addiction with psychologic effect"
df.loc[df["Addiction"] == 2, "Addiction"] = "Addiction without psychologic effect"
df
# Out:
#           Age   Gender  Education   Nscore   Escore   Oscore   Ascore  \
# 0     0.49788  0.48246   -0.05921  0.31287 -0.57545 -0.58331 -0.91699
# 1    -0.07854 -0.48246    1.98437 -0.67825  1.93886  1.43533  0.76096
# 2     0.49788 -0.48246   -0.05921 -0.46725  0.80523 -0.84732 -1.62090
# 3    -0.95197  0.48246    1.16365 -0.14882 -0.80615 -0.01928  0.59042
# 4     0.49788  0.48246    1.98437  0.73545 -1.63340 -0.45174 -0.30172
# ...       ...      ...        ...      ...      ...      ...      ...
# 1880 -0.95197  0.48246   -0.61113 -1.19430  1.74091  1.88511  0.76096
# 1881 -0.95197 -0.48246   -0.61113 -0.24649  1.74091  0.58331  0.76096
# 1882 -0.07854  0.48246    0.45468  1.13281 -1.37639 -1.27553 -1.77200
# 1883 -0.95197  0.48246   -0.61113  0.91093 -1.92173  0.29338 -1.62090
# 1884 -0.95197 -0.48246   -0.61113 -0.46725  2.12700  1.65653  1.11406
#
#        Cscore  Impulsive       SS  ...  Crack  Ecstasy  Heroin  Ketamine  \
# ...

# %%
df.to_csv("../Analyse_Exploratoire/data_multivariate.csv", index = False)
