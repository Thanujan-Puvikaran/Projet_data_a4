# %%
import pandas as pd
from IPython.display import HTML, display
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("data_preproc.csv")

# %%
correlation = df.corr()
correlation
# Out:
#                                                     net profit / total assets  \
# net profit / total assets                                            1.000000
# total liabilities / total assets                                     0.268892
# working capital / total assets                                      -0.271895
# current assets / short-term liabilities                              0.001285
# [(cash + short-term securities + receivables - ...                  -0.001064
# ...                                                                       ...
# sales / receivables                                                 -0.035938
# (short-term liabilities *365) / sales                                0.128880
# sales / short-term liabilities                                       0.010188
# sales / fixed asset                                                 -0.001634
# bankrupt                                                            -0.027089
#
#                                                     total liabilities / total assets  \
# net profit / total assets                                                   0.268892
# total liabilities / total assets                                            1.000000
# working capital / total assets                                             -0.997796
# current assets / short-term liabilities                                    -0.001445
# [(cash + short-term securities + receivables - ...                         -0.011349
# ...                                                                              ...
# sales / receivables                                                         0.001200
# (short-term liabilities *365) / sales                                       0.387945
# sales / short-term liabilities                                             -0.011432
# sales / fixed asset                                                         0.014535
# bankrupt                                                                    0.035560
#
#                                                     working capital / total assets  \
# net profit / total assets                                                -0.271895
# total liabilities / total assets                                         -0.997796
# working capital / total assets                                            1.000000
# current assets / short-term liabilities                                   0.002102
# [(cash + short-term securities + receivables - ...                        0.011179
# ...                                                                            ...
# sales / receivables                                                      -0.002905
# (short-term liabilities *365) / sales                                    -0.387685
# sales / short-term liabilities                                            0.014322
# sales / fixed asset                                                       0.036611
# bankrupt                                                                 -0.034292
#
#                                                     current assets / short-term liabilities  \
# net profit / total assets                                                          0.001285
# total liabilities / total assets                                                  -0.001445
# working capital / total assets                                                     0.002102
# current assets / short-term liabilities                                            1.000000
# [(cash + short-term securities + receivables - ...                                 0.001301
# ...                                                                                     ...
# sales / receivables                                                               -0.000548
# (short-term liabilities *365) / sales                                             -0.000348
# sales / short-term liabilities                                                     0.020293
# sales / fixed asset                                                               -0.000008
# bankrupt                                                                          -0.002071
#
#                                                     [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365  \
# net profit / total assets                                                                   -0.001064
# total liabilities / total assets                                                            -0.011349
# working capital / total assets                                                               0.011179
# current assets / short-term liabilities                                                      0.001301
# [(cash + short-term securities + receivables - ...                                           1.000000
# ...                                                                                               ...
# sales / receivables                                                                         -0.000430
# (short-term liabilities *365) / sales                                                       -0.005584
# sales / short-term liabilities                                                               0.002411
# sales / fixed asset                                                                          0.000738
# bankrupt                                                                                     0.002381
#
#                                                     retained earnings / total assets  \
# net profit / total assets                                                  -0.218187
# total liabilities / total assets                                           -0.986278
# working capital / total assets                                              0.984754
# current assets / short-term liabilities                                    -0.000040
# [(cash + short-term securities + receivables - ...                          0.010715
# ...                                                                              ...
# sales / receivables                                                        -0.001199
# (short-term liabilities *365) / sales                                      -0.382994
# sales / short-term liabilities                                              0.004500
# sales / fixed asset                                                        -0.009815
# bankrupt                                                                   -0.033081
#
#                                                     EBIT / total assets  \
# net profit / total assets                                      0.998670
# total liabilities / total assets                               0.266851
# working capital / total assets                                -0.269750
# current assets / short-term liabilities                        0.001164
# [(cash + short-term securities + receivables - ...            -0.000910
# ...                                                                 ...
# sales / receivables                                           -0.036171
# (short-term liabilities *365) / sales                          0.126973
# sales / short-term liabilities                                 0.012379
# sales / fixed asset                                            0.001575
# bankrupt                                                      -0.028521
#
#                                                     book value of equity / total liabilities  \
# net profit / total assets                                                           0.001902
# total liabilities / total assets                                                   -0.002495
# working capital / total assets                                                      0.001302
# current assets / short-term liabilities                                             0.729970
# [(cash + short-term securities + receivables - ...                                  0.001331
# ...                                                                                      ...
# sales / receivables                                                                 0.000270
# (short-term liabilities *365) / sales                                              -0.000107
# sales / short-term liabilities                                                      0.076768
# sales / fixed asset                                                                -0.001934
# bankrupt                                                                           -0.004709
#
#                                                     sales / total assets  \
# net profit / total assets                                      -0.055770
# total liabilities / total assets                                0.005357
# working capital / total assets                                 -0.004825
# current assets / short-term liabilities                        -0.002861
# [(cash + short-term securities + receivables - ...             -0.000431
# ...                                                                  ...
# sales / receivables                                             0.059324
# (short-term liabilities *365) / sales                          -0.000363
# sales / short-term liabilities                                  0.603221
# sales / fixed asset                                             0.036847
# bankrupt                                                       -0.001275
#
#                                                     equity / total assets  \
# net profit / total assets                                       -0.268475
# total liabilities / total assets                                -0.999671
# working capital / total assets                                   0.997925
# current assets / short-term liabilities                          0.001478
# [(cash + short-term securities + receivables - ...               0.011354
# ...                                                                   ...
# sales / receivables                                             -0.001165
# (short-term liabilities *365) / sales                           -0.387883
# sales / short-term liabilities                                   0.011374
# sales / fixed asset                                             -0.012806
# bankrupt                                                        -0.035747
#
#                                                     ...  \
# net profit / total assets                           ...
# total liabilities / total assets                    ...
# working capital / total assets                      ...
# current assets / short-term liabilities             ...
# [(cash + short-term securities + receivables - ...  ...
# ...                                                 ...
# sales / receivables                                 ...
# (short-term liabilities *365) / sales               ...
# sales / short-term liabilities                      ...
# sales / fixed asset                                 ...
# bankrupt                                            ...
#
#                                                     (sales - cost of products sold) / sales  \
# net profit / total assets                                                          0.008011
# total liabilities / total assets                                                  -0.001797
# working capital / total assets                                                     0.001387
# current assets / short-term liabilities                                            0.000504
# [(cash + short-term securities + receivables - ...                                -0.000195
# ...                                                                                     ...
# sales / receivables                                                                0.001824
# (short-term liabilities *365) / sales                                             -0.105301
# sales / short-term liabilities                                                     0.003272
# sales / fixed asset                                                                0.000931
# bankrupt                                                                           0.001850
#
#                                                     (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)  \
# net profit / total assets                                                                    0.048661
# total liabilities / total assets                                                            -0.000537
# working capital / total assets                                                               0.000413
# current assets / short-term liabilities                                                      0.000051
# [(cash + short-term securities + receivables - ...                                           0.000003
# ...                                                                                               ...
# sales / receivables                                                                          0.002047
# (short-term liabilities *365) / sales                                                       -0.000510
# sales / short-term liabilities                                                               0.002849
# sales / fixed asset                                                                          0.001104
# bankrupt                                                                                    -0.009320
#
#                                                     total costs /total sales  \
# net profit / total assets                                          -0.016774
# total liabilities / total assets                                    0.000636
# working capital / total assets                                     -0.000272
# current assets / short-term liabilities                            -0.002100
# [(cash + short-term securities + receivables - ...                  0.000101
# ...                                                                      ...
# sales / receivables                                                -0.002563
# (short-term liabilities *365) / sales                               0.059798
# sales / short-term liabilities                                     -0.004328
# sales / fixed asset                                                -0.001345
# bankrupt                                                           -0.003273
#
#                                                     long-term liabilities / equity  \
# net profit / total assets                                                -0.003583
# total liabilities / total assets                                          0.000872
# working capital / total assets                                           -0.000569
# current assets / short-term liabilities                                  -0.000564
# [(cash + short-term securities + receivables - ...                        0.000130
# ...                                                                            ...
# sales / receivables                                                      -0.001735
# (short-term liabilities *365) / sales                                     0.000448
# sales / short-term liabilities                                           -0.005251
# sales / fixed asset                                                      -0.001337
# bankrupt                                                                 -0.000432
#
#                                                     sales / inventory  \
# net profit / total assets                                    0.002481
# total liabilities / total assets                             0.001542
# working capital / total assets                               0.006461
# current assets / short-term liabilities                      0.004891
# [(cash + short-term securities + receivables - ...           0.000192
# ...                                                               ...
# sales / receivables                                         -0.001416
# (short-term liabilities *365) / sales                       -0.000769
# sales / short-term liabilities                               0.001666
# sales / fixed asset                                          0.006715
# bankrupt                                                    -0.003075
#
#                                                     sales / receivables  \
# net profit / total assets                                     -0.035938
# total liabilities / total assets                               0.001200
# working capital / total assets                                -0.002905
# current assets / short-term liabilities                       -0.000548
# [(cash + short-term securities + receivables - ...            -0.000430
# ...                                                                 ...
# sales / receivables                                            1.000000
# (short-term liabilities *365) / sales                         -0.000271
# sales / short-term liabilities                                 0.070326
# sales / fixed asset                                           -0.000515
# bankrupt                                                      -0.005393
#
#                                                     (short-term liabilities *365) / sales  \
# net profit / total assets                                                        0.128880
# total liabilities / total assets                                                 0.387945
# working capital / total assets                                                  -0.387685
# current assets / short-term liabilities                                         -0.000348
# [(cash + short-term securities + receivables - ...                              -0.005584
# ...                                                                                   ...
# sales / receivables                                                             -0.000271
# (short-term liabilities *365) / sales                                            1.000000
# sales / short-term liabilities                                                  -0.001068
# sales / fixed asset                                                              0.000313
# bankrupt                                                                         0.007041
#
#                                                     sales / short-term liabilities  \
# net profit / total assets                                                 0.010188
# total liabilities / total assets                                         -0.011432
# working capital / total assets                                            0.014322
# current assets / short-term liabilities                                   0.020293
# [(cash + short-term securities + receivables - ...                        0.002411
# ...                                                                            ...
# sales / receivables                                                       0.070326
# (short-term liabilities *365) / sales                                    -0.001068
# sales / short-term liabilities                                            1.000000
# sales / fixed asset                                                       0.016123
# bankrupt                                                                 -0.002172
#
#                                                     sales / fixed asset  \
# net profit / total assets                                     -0.001634
# total liabilities / total assets                               0.014535
# working capital / total assets                                 0.036611
# current assets / short-term liabilities                       -0.000008
# [(cash + short-term securities + receivables - ...             0.000738
# ...                                                                 ...
# sales / receivables                                           -0.000515
# (short-term liabilities *365) / sales                          0.000313
# sales / short-term liabilities                                 0.016123
# sales / fixed asset                                            1.000000
# bankrupt                                                      -0.000604
#
#                                                     bankrupt
# net profit / total assets                          -0.027089
# total liabilities / total assets                    0.035560
# working capital / total assets                     -0.034292
# current assets / short-term liabilities            -0.002071
# [(cash + short-term securities + receivables - ...  0.002381
# ...                                                      ...
# sales / receivables                                -0.005393
# (short-term liabilities *365) / sales               0.007041
# sales / short-term liabilities                     -0.002172
# sales / fixed asset                                -0.000604
# bankrupt                                            1.000000
#
# [65 rows x 65 columns]

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[:]

print("Top Absolute Correlations")
nos_correlation = pd.DataFrame(get_top_abs_correlations(correlation))
# Out:
# Top Absolute Correlations

# %%
main_correlation = nos_correlation[nos_correlation > 0.4].dropna()
display(HTML(main_correlation.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>EBIT / total assets</th>
#       <th>(gross profit + interest) / total assets</th>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>total liabilities / total assets</th>
#       <th>equity / total assets</th>
#       <td>0.999997</td>
#     </tr>
#     <tr>
#       <th>constant capital / total assets</th>
#       <th>short-term liabilities / total assets</th>
#       <td>0.999990</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">net profit / total assets</th>
#       <th>EBIT / total assets</th>
#       <td>0.999989</td>
#     </tr>
#     <tr>
#       <th>(gross profit + interest) / total assets</th>
#       <td>0.999989</td>
#     </tr>
#     <tr>
#       <th>gross profit / sales</th>
#       <th>net profit / sales</th>
#       <td>0.999984</td>
#     </tr>
#     <tr>
#       <th>current assets / short-term liabilities</th>
#       <th>(current assets - inventory) / short-term liabilities</th>
#       <td>0.999981</td>
#     </tr>
#     <tr>
#       <th>working capital / fixed assets</th>
#       <th>constant capital / fixed assets</th>
#       <td>0.999955</td>
#     </tr>
#     <tr>
#       <th>equity / total assets</th>
#       <th>constant capital / total assets</th>
#       <td>0.999954</td>
#     </tr>
#     <tr>
#       <th>total liabilities / total assets</th>
#       <th>constant capital / total assets</th>
#       <td>0.999946</td>
#     </tr>
#     <tr>
#       <th>EBIT / total assets</th>
#       <th>(gross profit + extraordinary items + financial expenses) / total assets</th>
#       <td>0.999943</td>
#     </tr>
#     <tr>
#       <th>(gross profit + extraordinary items + financial expenses) / total assets</th>
#       <th>(gross profit + interest) / total assets</th>
#       <td>0.999942</td>
#     </tr>
#     <tr>
#       <th>equity / total assets</th>
#       <th>short-term liabilities / total assets</th>
#       <td>0.999935</td>
#     </tr>
#     <tr>
#       <th>total liabilities / total assets</th>
#       <th>short-term liabilities / total assets</th>
#       <td>0.999935</td>
#     </tr>
#     <tr>
#       <th>net profit / total assets</th>
#       <th>(gross profit + extraordinary items + financial expenses) / total assets</th>
#       <td>0.999915</td>
#     </tr>
#     <tr>
#       <th>total liabilities / total assets</th>
#       <th>(equity - share capital) / total assets</th>
#       <td>0.999860</td>
#     </tr>
#     <tr>
#       <th>equity / total assets</th>
#       <th>(equity - share capital) / total assets</th>
#       <td>0.999857</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">(equity - share capital) / total assets</th>
#       <th>constant capital / total assets</th>
#       <td>0.999840</td>
#     </tr>
#     <tr>
#       <th>short-term liabilities / total assets</th>
#       <td>0.999808</td>
#     </tr>
#     <tr>
#       <th>(current assets - inventory) / short-term liabilities</th>
#       <th>current assets / total liabilities</th>
#       <td>0.999767</td>
#     </tr>
#     <tr>
#       <th>current assets / short-term liabilities</th>
#       <th>current assets / total liabilities</th>
#       <td>0.999732</td>
#     </tr>
#     <tr>
#       <th>book value of equity / total liabilities</th>
#       <th>total assets / total liabilities</th>
#       <td>0.999701</td>
#     </tr>
#     <tr>
#       <th>working capital / total assets</th>
#       <th>equity / total assets</th>
#       <td>0.999531</td>
#     </tr>
#     <tr>
#       <th>total liabilities / total assets</th>
#       <th>working capital / total assets</th>
#       <td>0.999523</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">working capital / total assets</th>
#       <th>constant capital / total assets</th>
#       <td>0.999365</td>
#     </tr>
#     <tr>
#       <th>short-term liabilities / total assets</th>
#       <td>0.999347</td>
#     </tr>
#     <tr>
#       <th>(gross profit + depreciation) / total liabilities</th>
#       <th>(net profit + depreciation) / total liabilities</th>
#       <td>0.999317</td>
#     </tr>
#     <tr>
#       <th>(sales - cost of products sold) / sales</th>
#       <th>total costs /total sales</th>
#       <td>0.999074</td>
#     </tr>
#     <tr>
#       <th>working capital / total assets</th>
#       <th>(equity - share capital) / total assets</th>
#       <td>0.999062</td>
#     </tr>
#     <tr>
#       <th>(total liabilities - cash) / sales</th>
#       <th>(short-term liabilities *365) / sales</th>
#       <td>0.998801</td>
#     </tr>
#     <tr>
#       <th>profit on operating activities / sales</th>
#       <th>EBITDA (profit on operating activities - depreciation) / sales</th>
#       <td>0.998776</td>
#     </tr>
#     <tr>
#       <th>retained earnings / total assets</th>
#       <th>(equity - share capital) / total assets</th>
#       <td>0.998643</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gross profit / short-term liabilities</th>
#       <th>(net profit + depreciation) / total liabilities</th>
#       <td>0.998429</td>
#     </tr>
#     <tr>
#       <th>(gross profit + depreciation) / total liabilities</th>
#       <td>0.998391</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">retained earnings / total assets</th>
#       <th>constant capital / total assets</th>
#       <td>0.998109</td>
#     </tr>
#     <tr>
#       <th>equity / total assets</th>
#       <td>0.998082</td>
#     </tr>
#     <tr>
#       <th>total liabilities / total assets</th>
#       <th>retained earnings / total assets</th>
#       <td>0.998041</td>
#     </tr>
#     <tr>
#       <th>retained earnings / total assets</th>
#       <th>short-term liabilities / total assets</th>
#       <td>0.997952</td>
#     </tr>
#     <tr>
#       <th>profit on operating activities / total assets</th>
#       <th>EBITDA (profit on operating activities - depreciation) / total assets</th>
#       <td>0.997907</td>
#     </tr>
#     <tr>
#       <th>(inventory * 365) / cost of products sold</th>
#       <th>(short-term liabilities * 365) / cost of products sold)</th>
#       <td>0.996929</td>
#     </tr>
#     <tr>
#       <th>equity / fixed assets</th>
#       <th>constant capital / fixed assets</th>
#       <td>0.996901</td>
#     </tr>
#     <tr>
#       <th>working capital / total assets</th>
#       <th>retained earnings / total assets</th>
#       <td>0.996774</td>
#     </tr>
#     <tr>
#       <th>gross profit / sales</th>
#       <th>(gross profit + interest) / sales</th>
#       <td>0.996487</td>
#     </tr>
#     <tr>
#       <th>working capital / fixed assets</th>
#       <th>equity / fixed assets</th>
#       <td>0.996455</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">net profit / sales</th>
#       <th>(gross profit + interest) / sales</th>
#       <td>0.996288</td>
#     </tr>
#     <tr>
#       <th>profit on operating activities / sales</th>
#       <td>0.996270</td>
#     </tr>
#     <tr>
#       <th>profit on operating activities / total assets</th>
#       <th>profit on sales / total assets</th>
#       <td>0.996144</td>
#     </tr>
#     <tr>
#       <th>gross profit / sales</th>
#       <th>profit on operating activities / sales</th>
#       <td>0.996090</td>
#     </tr>
#     <tr>
#       <th>net profit / sales</th>
#       <th>EBITDA (profit on operating activities - depreciation) / sales</th>
#       <td>0.995670</td>
#     </tr>
#     <tr>
#       <th>gross profit / sales</th>
#       <th>EBITDA (profit on operating activities - depreciation) / sales</th>
#       <td>0.995477</td>
#     </tr>
#     <tr>
#       <th>(current liabilities * 365) / cost of products sold</th>
#       <th>(short-term liabilities * 365) / cost of products sold)</th>
#       <td>0.995348</td>
#     </tr>
#     <tr>
#       <th>profit on sales / total assets</th>
#       <th>EBITDA (profit on operating activities - depreciation) / total assets</th>
#       <td>0.994279</td>
#     </tr>
#     <tr>
#       <th>(current liabilities * 365) / cost of products sold</th>
#       <th>(inventory * 365) / cost of products sold</th>
#       <td>0.993456</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">(gross profit + interest) / sales</th>
#       <th>EBITDA (profit on operating activities - depreciation) / sales</th>
#       <td>0.989526</td>
#     </tr>
#     <t

# %%
display(HTML(main_correlation.reset_index(level=[1]).to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>level_1</th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>EBIT / total assets</th>
#       <td>(gross profit + interest) / total assets</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>total liabilities / total assets</th>
#       <td>equity / total assets</td>
#       <td>0.999997</td>
#     </tr>
#     <tr>
#       <th>constant capital / total assets</th>
#       <td>short-term liabilities / total assets</td>
#       <td>0.999990</td>
#     </tr>
#     <tr>
#       <th>net profit / total assets</th>
#       <td>EBIT / total assets</td>
#       <td>0.999989</td>
#     </tr>
#     <tr>
#       <th>net profit / total assets</th>
#       <td>(gross profit + interest) / total assets</td>
#       <td>0.999989</td>
#     </tr>
#     <tr>
#       <th>gross profit / sales</th>
#       <td>net profit / sales</td>
#       <td>0.999984</td>
#     </tr>
#     <tr>
#       <th>current assets / short-term liabilities</th>
#       <td>(current assets - inventory) / short-term liabilities</td>
#       <td>0.999981</td>
#     </tr>
#     <tr>
#       <th>working capital / fixed assets</th>
#       <td>constant capital / fixed assets</td>
#       <td>0.999955</td>
#     </tr>
#     <tr>
#       <th>equity / total assets</th>
#       <td>constant capital / total assets</td>
#       <td>0.999954</td>
#     </tr>
#     <tr>
#       <th>total liabilities / total assets</th>
#       <td>constant capital / total assets</td>
#       <td>0.999946</td>
#     </tr>
#     <tr>
#       <th>EBIT / total assets</th>
#       <td>(gross profit + extraordinary items + financial expenses) / total assets</td>
#       <td>0.999943</td>
#     </tr>
#     <tr>
#       <th>(gross profit + extraordinary items + financial expenses) / total assets</th>
#       <td>(gross profit + interest) / total assets</td>
#       <td>0.999942</td>
#     </tr>
#     <tr>
#       <th>equity / total assets</th>
#       <td>short-term liabilities / total assets</td>
#       <td>0.999935</td>
#     </tr>
#     <tr>
#       <th>total liabilities / total assets</th>
#       <td>short-term liabilities / total assets</td>
#       <td>0.999935</td>
#     </tr>
#     <tr>
#       <th>net profit / total assets</th>
#       <td>(gross profit + extraordinary items + financial expenses) / total assets</td>
#       <td>0.999915</td>
#     </tr>
#     <tr>
#       <th>total liabilities / total assets</th>
#       <td>(equity - share capital) / total assets</td>
#       <td>0.999860</td>
#     </tr>
#     <tr>
#       <th>equity / total assets</th>
#       <td>(equity - share capital) / total assets</td>
#       <td>0.999857</td>
#     </tr>
#     <tr>
#       <th>(equity - share capital) / total assets</th>
#       <td>constant capital / total assets</td>
#       <td>0.999840</td>
#     </tr>
#     <tr>
#       <th>(equity - share capital) / total assets</th>
#       <td>short-term liabilities / total assets</td>
#       <td>0.999808</td>
#     </tr>
#     <tr>
#       <th>(current assets - inventory) / short-term liabilities</th>
#       <td>current assets / total liabilities</td>
#       <td>0.999767</td>
#     </tr>
#     <tr>
#       <th>current assets / short-term liabilities</th>
#       <td>current assets / total liabilities</td>
#       <td>0.999732</td>
#     </tr>
#     <tr>
#       <th>book value of equity / total liabilities</th>
#       <td>total assets / total liabilities</td>
#       <td>0.999701</td>
#     </tr>
#     <tr>
#       <th>working capital / total assets</th>
#       <td>equity / total assets</td>
#       <td>0.999531</td>
#     </tr>
#     <tr>
#       <th>total liabilities / total assets</th>
#       <td>working capital / total assets</td>
#       <td>0.999523</td>
#     </tr>
#     <tr>
#       <th>working capital / total assets</th>
#       <td>constant capital / total assets</td>
#       <td>0.999365</td>
#     </tr>
#     <tr>
#       <th>working capital / total assets</th>
#       <td>short-term liabilities / total assets</td>
#       <td>0.999347</td>
#     </tr>
#     <tr>
#       <th>(gross profit + depreciation) / total liabilities</th>
#       <td>(net profit + depreciation) / total liabilities</td>
#       <td>0.999317</td>
#     </tr>
#     <tr>
#       <th>(sales - cost of products sold) / sales</th>
#       <td>total costs /total sales</td>
#       <td>0.999074</td>
#     </tr>
#     <tr>
#       <th>working capital / total assets</th>
#       <td>(equity - share capital) / total assets</td>
#       <td>0.999062</td>
#     </tr>
#     <tr>
#       <th>(total liabilities - cash) / sales</th>
#       <td>(short-term liabilities *365) / sales</td>
#       <td>0.998801</td>
#     </tr>
#     <tr>
#       <th>profit on operating activities / sales</th>
#       <td>EBITDA (profit on operating activities - depreciation) / sales</td>
#       <td>0.998776</td>
#     </tr>
#     <tr>
#       <th>retained earnings / total assets</th>
#       <td>(equity - share capital) / total assets</td>
#       <td>0.998643</td>
#     </tr>
#     <tr>
#       <th>gross profit / short-term liabilities</th>
#       <td>(net profit + depreciation) / total liabilities</td>
#       <td>0.998429</td>
#     </tr>
#     <tr>
#       <th>gross profit / short-term liabilities</th>
#       <td>(gross profit + depreciation) / total liabilities</td>
#       <td>0.998391</td>
#     </tr>
#     <tr>
#       <th>retained earnings / total assets</th>
#       <td>constant capital / total assets</td>
#       <td>0.998109</td>
#     </tr>
#     <tr>
#       <th>retained earnings / total assets</th>
#       <td>equity / total assets</td>
#       <td>0.998082</td>
#     </tr>
#     <tr>
#       <th>total liabilities / total assets</th>
#       <td>retained earnings / total assets</td>
#       <td>0.998041</td>
#     </tr>
#     <tr>
#       <th>retained earnings / total assets</th>
#       <td>short-term liabilities / total assets</td>
#       <td>0.997952</td>
#     </tr>
#     <tr>
#       <th>profit on operating activities / total assets</th>
#       <td>EBITDA (profit on operating activities - depreciation) / total assets</td>
#       <td>0.997907</td>
#     </tr>
#     <tr>
#       <th>(inventory * 365) / cost of products sold</th>
#       <td>(short-term liabilities * 365) / cost of products sold)</td>
#       <td>0.996929</td>
#     </tr>
#     <tr>
#       <th>equity / fixed assets</th>
#       <td>constant capital / fixed assets</td>
#       <td>0.996901</td>
#     </tr>
#     <tr>
#       <th>working capital / total assets</th>
#       <td>retained earnings / total assets</td>
#       <td>0.996774</td>
#     </tr>
#     <tr>
#       <th>gross profit / sales</th>
#       <td>(gross profit + interest) / sales</td>
#       <td>0.996487</td>
#     </tr>
#     <tr>
#       <th>working capital / fixed assets</th>
#       <td>equity / fixed assets</td>
#       <td>0.996455</td>
#     </tr>
#     <tr>
#       <th>net profit / sales</th>
#       <td>(gross profit + interest) / sales</td>
#       <td>0.996288</td>
#     </tr>
#     <tr>
#       <th>net profit / sales</th>
#       <td>profit on operating activities / sales</td>
#       <td>0.996270</td>
#     </tr>
#     <tr>
#       <th>profit on operating activities / total assets</th>
#       <td>profit on sales / total assets</td>
#       <td>0.996144</td>
#     </tr>
#     <tr>
#       <th>gross profit / sales</th>
#       <td>profit on operating activities / sales</td>
#       <td>0.996090</td>
#     </tr>
#     <tr>
#       <th>net profit / sales</th>
#       <td>EBITDA (profit on operating activities - depreciation) / sales</td>
#       <td>0.995670</td>
#     </tr>
#     <tr>
#       <th>gross profit / sales</th>
#       <td>EBITDA (profit on operating activities - depreciation) / sales</td>
#       <td>0.995477</td>
#     </tr>
#     <tr>
#       <th>(current liabilities * 365) / cost of products sold</th>
#       <td>(short-term liabilities * 365) / cost of products sold)</td>
#       <td>0.995348</td>
#     </tr>
#     <tr>
#       <th>profit on sales / total assets</th>
#       <td>EBITDA (profit on operating activities - depreciation) / total assets</td>
#       <td>0.994279</td>
#     </tr>
#     <tr>
#       <th>(current liabilities * 365) / cost of products sold</th>
#       <td>(inventory * 365) / cost of products sold</td>
#       <td>0.993456</td>
#     </tr>
#     <tr>
#       <th>(gross profit + interest) / sales</th>
#       <td

# %%
list(main_correlation.reset_index(level=[0]).index)
# Out:
# ['(gross profit + interest) / total assets',
#  'equity / total assets',
#  'short-term liabilities / total assets',
#  'EBIT / total assets',
#  '(gross profit + interest) / total assets',
#  'net profit / sales',
#  '(current assets - inventory) / short-term liabilities',
#  'constant capital / fixed assets',
#  'constant capital / total assets',
#  'constant capital / total assets',
#  '(gross profit + extraordinary items + financial expenses) / total assets',
#  '(gross profit + interest) / total assets',
#  'short-term liabilities / total assets',
#  'short-term liabilities / total assets',
#  '(gross profit + extraordinary items + financial expenses) / total assets',
#  '(equity - share capital) / total assets',
#  '(equity - share capital) / total assets',
#  'constant capital / total assets',
#  'short-term liabilities / total assets',
#  'current assets / total liabilities',
#  'current assets / total liabilities',
#  'total assets / total liabilities',
#  'equity / total assets',
#  'working capital / total assets',
#  'constant capital / total assets',
#  'short-term liabilities / total assets',
#  '(net profit + depreciation) / total liabilities',
#  'total costs /total sales',
#  '(equity - share capital) / total assets',
#  '(short-term liabilities *365) / sales',
#  'EBITDA (profit on operating activities - depreciation) / sales',
#  '(equity - share capital) / total assets',
#  '(net profit + depreciation) / total liabilities',
#  '(gross profit + depreciation) / total liabilities',
#  'constant capital / total assets',
#  'equity / total assets',
#  'retained earnings / total assets',
#  'short-term liabilities / total assets',
#  'EBITDA (profit on operating activities - depreciation) / total assets',
#  '(short-term liabilities * 365) / cost of products sold)',
#  'constant capital / fixed assets',
#  'retained earnings / total assets',
#  '(gross profit + interest) / sales',
#  'equity / fixed assets',
#  '(gross profit + interest) / sales',
#  'profit on operating activities / sales',
#  'profit on sales / total assets',
#  'profit on operating activities / sales',
#  'EBITDA (profit on operating activities - depreciation) / sales',
#  'EBITDA (profit on operating activities - depreciation) / sales',
#  '(short-term liabilities * 365) / cost of products sold)',
#  'EBITDA (profit on operating activities - depreciation) / total assets',
#  '(inventory * 365) / cost of products sold',
#  'EBITDA (profit on operating activities - depreciation) / sales',
#  'profit on operating activities / sales',
#  'long-term liabilities / equity',
#  '(receivables * 365) / sales',
#  '(current assets - inventory - receivables) / short-term liabilities',
#  '(current assets - inventory) / short-term liabilities',
#  'profit on operating activities / total assets',
#  'profit on operating activities / total assets',
#  'profit on operating activities / total assets',
#  'profit on operating activities / total assets',
#  'current assets / total liabilities',
#  'EBITDA (profit on operating activities - depreciation) / total assets',
#  'EBITDA (profit on operating activities - depreciation) / total assets',
#  'EBITDA (profit on operating activities - depreciation) / total assets',
#  'EBITDA (profit on operating activities - depreciation) / total assets',
#  'profit on sales / total assets',
#  'profit on sales / total assets',
#  'profit on sales / total assets',
#  'profit on sales / total assets',
#  'sales / fixed asset',
#  'sales / fixed asset',
#  'profit on sales / total assets',
#  'gross profit / total assets',
#  'profit on operating activities / sales',
#  'gross profit / total assets',
#  'gross profit / total assets',
#  'gross profit / total assets',
#  'operating expenses / total liabilities',
#  'sales / fixed asset',
#  'EBITDA (profit on operating activities - depreciation) / total assets',
#  'current assets / total liabilities',
#  'book value of equity / total liabilities',
#  '(current assets - inventory) / short-term liabilities',
#  '(sales - cost of products sold) / sales',
#  'EBITDA (profit on operating activities - depreciation) / sales',
#  'profit on sales / sales',
#  'profit on sales / sales',
#  'current assets / total liabilities',
#  'total costs /total sales',
#  'total assets / total liabilities',
#  '(current assets - inventory) / short-term liabilities',
#  'profit on operating activities / total assets',
#  'EBITDA (profit on operating activities - depreciation) / total assets',
#  'operating expenses / total liabilities',
#  'operating expenses / total liabilities',
#  'operating expenses / total liabilities',
#  'operating expenses / total liabilities',
#  '(current assets - inventory - receivables) / short-term liabilities',
#  'profit on sales / sales',
#  '(current assets - inventory - receivables) / short-term liabilities',
#  'profit on sales / total assets',
#  'sales / inventory',
#  'rotation receivables + inventory turnover in days',
#  '(current assets - inventory - receivables) / short-term liabilities',
#  'operating expenses / total liabilities',
#  'operating expenses / total liabilities',
#  'operating expenses / total liabilities',
#  'operating expenses / total liabilities',
#  'profit on sales / total assets',
#  'profit on sales / total assets',
#  '(net profit + depreciation) / total liabilities',
#  'profit on sales / total assets',
#  'EBITDA (profit on operating activities - depreciation) / total assets',
#  'profit on operating activities / total assets',
#  'sales / short-term liabilities',
#  'EBITDA (profit on operating activities - depreciation) / total assets',
#  'profit on operating activities / total assets',
#  'EBITDA (profit on operating activities - depreciation) / total assets',
#  '(receivables * 365) / sales',
#  'operating expenses / short-term liabilities',
#  '(net profit + depreciation) / total liabilities',
#  '(net profit + depreciation) / total liabilities',
#  '(net profit + depreciation) / total liabilities',
#  '(current assets - inventory) / short-term liabilities',
#  '(net profit + depreciation) / total liabilities',
#  'current assets / total liabilities',
#  'gross profit / short-term liabilities',
#  'gross profit / short-term liabilities',
#  '(gross profit + interest) / total assets',
#  'gross profit / short-term liabilities',
#  '(gross profit + depreciation) / total liabilities',
#  '(gross profit + depreciation) / total liabilities',
#  '(gross profit + depreciation) / total liabilities',
#  '(gross profit + depreciation) / total liabilities',
#  '(sales - cost of products sold) / sales',
#  'EBITDA (profit on operating activities - depreciation) / sales',
#  'total costs /total sales',
#  'EBITDA (profit on operating activities - depreciation) / sales',
#  'rotation receivables + inventory turnover in days',
#  'rotation receivables + inventory turnover in days',
#  'rotation receivables + inventory turnover in days',
#  '(short-term liabilities *365) / sales',
#  '(short-term liabilities *365) / sales',
#  '(short-term liabilities *365) / sales',
#  '(short-term liabilities *365) / sales',
#  '(short-term liabilities *365) / sales',
#  '(short-term liabilities *365) / sales',
#  '(short-term liabilities *365) / sales',
#  'rotation receivables + inventory turnover in days',
#  '(total liabilities - cash) / sales',
#  '(total liabilities - cash) / sales',
#  '(total liabilities - cash) / sales',
#  '(total liabilities - cash) / sales',
#  '(total liabilities - cash) / sales',
#  'constant capital / total assets',
#  'short-term liabilities / total assets',
#  '(receivables * 365) / sales',
#  '(receivables * 365) / sales',
#  '(receivables * 365) / sales',
#  '(receivables * 365) / sales',
#  'gross profit (in 3 years) / total assets',
#  '(net profit + depreciation) / total liabilities',
#  'gross profit / total assets',
#  'gross profit / total assets',
#  'operating expenses / short-term liabilities',
#  'operating expenses / short-term liabilities',
#  '(equity - share capital) / total assets',
#  'gross profit (in 3 years) / total assets',
#  'gross profit (in 3 years) / total assets',
#  'constant capital / total assets',
#  'short-term liabilities / total assets',
#  'gross profit (in 3 years) / total assets',
#  'sales / short-term liabilities',
#  '(short-term liabilities *365) / sales',
#  'profit on sales / sales',
#  'EBITDA (profit on operating activities - depreciation) / sales',
#  '(gross profit + interest) / sales',
#  'net profit / sales',
#  '(inventory * 365) / sales',
#  'profit on operating activities / sales',
#  '(sales - cost of products sold) / sales',
#  'total costs /total sales',
#  '(receivables * 365) / sales',
#  'rotation receivables + inventory turnover in days',
#  'total sales / total assets',
#  '(short-term liabilities *365) / sales',
#  '(total liabilities - cash) / sales',
#  'total sales / total assets',
#  'short-term liabilities / total assets',
#  'total sales / total assets',
#  'constant capital / total assets',
#  'total sales / total assets',
#  'total sales / total assets',
#  '(short-term liabilities *365) / sales',
#  'total sales / total assets',
#  'profit on operating activities / sales',
#  '(short-term liabilities *365) / sales',
#  'EBITDA (profit on operating activities - depreciation) / sales',
#  'profit on sales / total assets',
#  'working capital / total assets',
#  '(gross profit + extraordinary items + financial expenses) / total assets',
#  '(gross profit + interest) / total assets',
#  'EBIT / total assets',
#  'short-term liabilities / total assets',
#  'short-term liabilities / total assets',
#  'gross profit / total assets',
#  'short-term liabilities / total assets',
#  'short-term liabilities / total assets',
#  'constant capital / total assets',
#  'total liabilities / total assets',
#  'equity / total assets',
#  'constant capital / total assets',
#  '(gross profit + extraordinary items + financial expenses) / total assets',
#  '(gross profit + extraordinary items + financial expenses) / total assets',
#  'constant capital / total assets',
#  'constant capital / total assets',
#  '(gross profit + interest) / total assets',
#  'EBIT / total assets',
#  '(gross profit + interest) / total assets',
#  'equity / total assets',
#  '(equity - share capital) / total assets',
#  '(equity - share capital) / total assets',
#  '(equity - share capital) / total assets',
#  '(equity - share capital) / total assets',
#  'profit on sales / sales',
#  'profit on operating activities / sales',
#  'gross profit / total assets',
#  'short-term liabilities / total assets',
#  'constant capital / total assets',
#  'gross profit / total assets',
#  'gross profit / total assets',
#  'gross profit / sales',
#  'net profit / sales',
#  '(gross profit + interest) / sales',
#  '(equity - share capital) / total assets']

# %%
aretirer = list(main_correlation.reset_index(level=[0]).index)
mySet = set(aretirer)
print(mySet)
# Out:
# {'(gross profit + extraordinary items + financial expenses) / total assets', 'profit on operating activities / total assets', 'gross profit (in 3 years) / total assets', 'gross profit / total assets', '(gross profit + interest) / total assets', 'gross profit / short-term liabilities', 'equity / total assets', '(current assets - inventory - receivables) / short-term liabilities', '(current assets - inventory) / short-term liabilities', '(equity - share capital) / total assets', 'gross profit / sales', 'EBITDA (profit on operating activities - depreciation) / total assets', '(short-term liabilities * 365) / cost of products sold)', 'constant capital / fixed assets', '(net profit + depreciation) / total liabilities', '(receivables * 365) / sales', 'total costs /total sales', 'profit on sales / total assets', 'short-term liabilities / total assets', 'net profit / sales', 'sales / fixed asset', 'operating expenses / total liabilities', 'profit on sales / sales', '(total liabilities - cash) / sales', '(short-term liabilities *365) / sales', 'sales / inventory', 'operating expenses / short-term liabilities', 'equity / fixed assets', 'working capital / total assets', 'total sales / total assets', 'retained earnings / total assets', 'total liabilities / total assets', '(inventory * 365) / sales', 'total assets / total liabilities', 'book value of equity / total liabilities', 'current assets / total liabilities', 'long-term liabilities / equity', '(gross profit + interest) / sales', 'EBITDA (profit on operating activities - depreciation) / sales', '(gross profit + depreciation) / total liabilities', 'sales / short-term liabilities', 'profit on operating activities / sales', 'constant capital / total assets', 'rotation receivables + inventory turnover in days', 'EBIT / total assets', '(inventory * 365) / cost of products sold', '(sales - cost of products sold) / sales'}

# %%
df_clean = df.drop(list(mySet), axis = 1)
df_clean
# Out:
#        net profit / total assets  current assets / short-term liabilities  \
# 0                       0.174190                                  1.34800
# 1                       0.146240                                  1.62940
# 2                       0.000595                                  3.15990
# 3                       0.024526                                  1.78330
# 4                       0.188290                                  1.92790
# ...                          ...                                      ...
# 10498                   0.002861                                  0.51658
# 10499                  -0.051968                                  2.16980
# 10500                  -0.135900                                  0.46526
# 10501                   0.009423                                  1.52300
# 10502                  -0.001775                                  1.00450
#
#        [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365  \
# 0                                               -28.9820
# 1                                                 2.5952
# 2                                                84.8740
# 3                                               -10.1050
# 4                                               -58.2740
# ...                                                  ...
# 10498                                           -31.8660
# 10499                                            12.7480
# 10500                                          -145.3100
# 10501                                           -10.1580
# 10502                                           -50.2210
#
#        sales / total assets  (gross profit + depreciation) / sales  \
# 0                   1.19610                               0.142330
# 1                   1.60180                               0.126470
# 2                   1.00770                               0.030966
# 3                   1.05090                               0.036812
# 4                   1.33930                               0.187800
# ...                     ...                                    ...
# 10498               1.01200                               0.018378
# 10499               0.94694                               0.020928
# 10500               1.09990                              -0.119880
# 10501               1.01230                               0.014470
# 10502               2.12680                               0.011297
#
#        (total liabilities * 365) / (gross profit + depreciation)  \
# 0                                                 592.24
# 1                                                 829.46
# 2                                                2094.10
# 3                                                3299.40
# 4                                                 602.31
# ...                                                  ...
# 10498                                            2879.30
# 10499                                            6875.90
# 10500                                           -2324.00
# 10501                                            6789.00
# 10502                                           14398.00
#
#        sales (n) / sales (n-1)  \
# 0                      0.99690
# 1                      5.08890
# 2                      0.67451
# 3                      0.62795
# 4                      1.20390
# ...                        ...
# 10498                  0.98388
# 10499                  0.72732
# 10500                      NaN
# 10501                  0.75106
# 10502                  1.25140
#
#        profit on operating activities / financial expenses  \
# 0                                                1.97370
# 1                                               44.59300
# 2                                                0.32153
# 3                                                0.44844
# 4                                               44.94700
# ...                                                  ...
# 10498                                                NaN
# 10499                                                NaN
# 10500                                           -2.76940
# 10501                                                NaN
# 10502                                            0.89387
#
#        working capital / fixed assets  logarithm of total assets  \
# 0                            0.324170                     5.9473
# 1                            1.048600                     4.0792
# 2                            1.710700                     4.6220
# 3                            0.738690                     4.2600
# 4                            1.185300                     4.6033
# ...                               ...                        ...
# 10498                       -0.294260                     4.2857
# 10499                        0.202390                     4.9622
# 10500                       -0.486890                     4.0926
# 10501                        1.098900                     4.0116
# 10502                        0.021433                     3.1274
#
#        (current liabilities * 365) / cost of products sold  \
# 0                                                100.820
# 1                                                105.090
# 2                                                 65.345
# 3                                                103.810
# 4                                                122.090
# ...                                                  ...
# 10498                                             42.707
# 10499                                             31.023
# 10500                                            247.970
# 10501                                             99.452
# 10502                                            144.560
#
#        (current assets - inventories) / long-term liabilities  \
# 0                                           123140.00000
# 1                                                    NaN
# 2                                                    NaN
# 3                                                3.96240
# 4                                                4.54900
# ...                                                  ...
# 10498                                            1.14150
# 10499                                            0.41299
# 10500                                            0.93568
# 10501                                                NaN
# 10502                                            4.34600
#
#        total liabilities / ((profit on operating activities + depreciation) * (12/365))  \
# 0                                               0.041124
# 1                                               0.074333
# 2                                               0.098528
# 3                                               0.180500
# 4                                               0.054712
# ...                                                  ...
# 10498                                           0.195420
# 10499                                           0.903660
# 10500                                          -0.287440
# 10501                                           0.386400
# 10502                                           0.435240
#
#        net profit / inventory  working capital  \
# 0                    0.946210         127280.0
# 1                    0.546690           3387.8
# 2                    0.003168          20453.0
# 3                    0.079819           5012.6
# 4                    0.364290          13730.0
# ...                       ...              ...
# 10498                0.027246          -4321.5
# 10499               -0.537390          13488.0
# 10500               -0.775120          -4233.0
# 10501                0.030251           2686.9
# 10502               -0.006301              5.0
#
#        (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)  \
# 0                                               0.375740
# 1                                               0.271000
# 2                                               0.000881
# 3                                               0.043445
# 4                                               0.321880
# ...                                                  ...
# 10498                                           0.007966
# 10499                                          -0.140410
# 10500                                          -0.846930
# 10501                                           0.019027
# 10502                                          -0.033971
#
#        sales / receivables  bankrupt
# 0                   6.2813         0
# 1                   4.1103         0
# 2                   3.7922         0
# 3                   5.0528         0
# 4                   7.0756         0
# ...                    ...       ...
# 10498              39.1500         1
# 10499               9.2851         1
# 10500               9.6966         1
# 10501               4.3536         1
# 10502               3.9960         1
#
# [10503 rows x 18 columns]

# %%
correlation2 = df_clean.corr()
correlation2
# Out:
#                                                     net profit / total assets  \
# net profit / total assets                                            1.000000
# current assets / short-term liabilities                              0.001285
# [(cash + short-term securities + receivables - ...                  -0.001064
# sales / total assets                                                -0.055770
# (gross profit + depreciation) / sales                                0.015829
# (total liabilities * 365) / (gross profit + dep...                   0.000241
# sales (n) / sales (n-1)                                             -0.004088
# profit on operating activities / financial expe...                   0.019734
# working capital / fixed assets                                       0.020467
# logarithm of total assets                                            0.023342
# (current liabilities * 365) / cost of products ...                   0.020267
# (current assets - inventories) / long-term liab...                   0.005553
# total liabilities / ((profit on operating activ...                   0.001714
# net profit / inventory                                               0.009620
# working capital                                                      0.012158
# (current assets - inventory - short-term liabil...                   0.048661
# sales / receivables                                                 -0.035938
# bankrupt                                                            -0.027089
#
#                                                     current assets / short-term liabilities  \
# net profit / total assets                                                          0.001285
# current assets / short-term liabilities                                            1.000000
# [(cash + short-term securities + receivables - ...                                 0.001301
# sales / total assets                                                              -0.002861
# (gross profit + depreciation) / sales                                             -0.002223
# (total liabilities * 365) / (gross profit + dep...                                -0.000411
# sales (n) / sales (n-1)                                                           -0.001212
# profit on operating activities / financial expe...                                -0.000550
# working capital / fixed assets                                                     0.021738
# logarithm of total assets                                                         -0.020382
# (current liabilities * 365) / cost of products ...                                -0.000276
# (current assets - inventories) / long-term liab...                                 0.001271
# total liabilities / ((profit on operating activ...                                -0.000165
# net profit / inventory                                                             0.038634
# working capital                                                                   -0.000513
# (current assets - inventory - short-term liabil...                                 0.000051
# sales / receivables                                                               -0.000548
# bankrupt                                                                          -0.002071
#
#                                                     [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365  \
# net profit / total assets                                                                   -0.001064
# current assets / short-term liabilities                                                      0.001301
# [(cash + short-term securities + receivables - ...                                           1.000000
# sales / total assets                                                                        -0.000431
# (gross profit + depreciation) / sales                                                        0.000175
# (total liabilities * 365) / (gross profit + dep...                                          -0.000308
# sales (n) / sales (n-1)                                                                      0.000109
# profit on operating activities / financial expe...                                           0.000500
# working capital / fixed assets                                                               0.000826
# logarithm of total assets                                                                   -0.000292
# (current liabilities * 365) / cost of products ...                                          -0.000258
# (current assets - inventories) / long-term liab...                                           0.000622
# total liabilities / ((profit on operating activ...                                           0.000123
# net profit / inventory                                                                       0.000270
# working capital                                                                              0.001235
# (current assets - inventory - short-term liabil...                                           0.000003
# sales / receivables                                                                         -0.000430
# bankrupt                                                                                     0.002381
#
#                                                     sales / total assets  \
# net profit / total assets                                      -0.055770
# current assets / short-term liabilities                        -0.002861
# [(cash + short-term securities + receivables - ...             -0.000431
# sales / total assets                                            1.000000
# (gross profit + depreciation) / sales                           0.000041
# (total liabilities * 365) / (gross profit + dep...              0.003530
# sales (n) / sales (n-1)                                        -0.001569
# profit on operating activities / financial expe...              0.004898
# working capital / fixed assets                                  0.004142
# logarithm of total assets                                      -0.076267
# (current liabilities * 365) / cost of products ...              0.002045
# (current assets - inventories) / long-term liab...             -0.002945
# total liabilities / ((profit on operating activ...             -0.000485
# net profit / inventory                                          0.016209
# working capital                                                -0.008492
# (current assets - inventory - short-term liabil...              0.002789
# sales / receivables                                             0.059324
# bankrupt                                                       -0.001275
#
#                                                     (gross profit + depreciation) / sales  \
# net profit / total assets                                                        0.015829
# current assets / short-term liabilities                                         -0.002223
# [(cash + short-term securities + receivables - ...                               0.000175
# sales / total assets                                                             0.000041
# (gross profit + depreciation) / sales                                            1.000000
# (total liabilities * 365) / (gross profit + dep...                              -0.000165
# sales (n) / sales (n-1)                                                         -0.000266
# profit on operating activities / financial expe...                              -0.000150
# working capital / fixed assets                                                  -0.000171
# logarithm of total assets                                                       -0.043398
# (current liabilities * 365) / cost of products ...                               0.000718
# (current assets - inventories) / long-term liab...                              -0.000463
# total liabilities / ((profit on operating activ...                               0.000261
# net profit / inventory                                                           0.000498
# working capital                                                                 -0.000663
# (current assets - inventory - short-term liabil...                               0.001087
# sales / receivables                                                             -0.000645
# bankrupt                                                                        -0.001432
#
#                                                     (total liabilities * 365) / (gross profit + depreciation)  \
# net profit / total assets                                                                    0.000241
# current assets / short-term liabilities                                                     -0.000411
# [(cash + short-term securities + receivables - ...                                          -0.000308
# sales / total assets                                                                         0.003530
# (gross profit + depreciation) / sales                                                       -0.000165
# (total liabilities * 365) / (gross profit + dep...                                           1.000000
# sales (n) / sales (n-1)                                                                     -0.000898
# profit on operating activities / financial expe...                                          -0.001278
# working capital / fixed assets                                                               0.000909
# logarithm of total assets                                                                   -0.023823
# (current liabilities * 365) / cost of products ...                                          -0.000443
# (current assets - inventories) / long-term liab...                                          -0.001469
# total liabilities / ((profit on operating activ...                                          -0.002262
# net profit / inventory                                                                       0.000002
# working capital                                                                             -0.001293
# (current assets - inventory - short-term liabil...                                           0.000645
# sales / receivables                                                                         -0.002593
# bankrupt                                                                                     0.004495
#
#                                                     sales (n) / sales (n-1)  \
# net profit / total assets                                         -0.004088
# current assets / short-term liabilities                           -0.001212
# [(cash + short-term securities + receivables - ...                 0.000109
# sales / total assets                                              -0.001569
# (gross profit + depreciation) / sales                             -0.000266
# (total liabilities * 365) / (gross profit + dep...                -0.000898
# sales (n) / sales (n-1)                                            1.000000
# profit on operating activities / financial expe...                -0.000420
# working capital / fixed assets                                    -0.000739
# logarithm of total assets                                          0.023338
# (current liabilities * 365) / cost of products ...                -0.000116
# (current assets - inventories) / long-term liab...                -0.000661
# total liabilities / ((profit on operating activ...                -0.000112
# net profit / inventory                                            -0.000107
# working capital                                                   -0.011104
# (current assets - inventory - short-term liabil...                -0.000309
# sales / receivables                                               -0.001582
# bankrupt                                                          -0.002301
#
#                                                     profit on operating activities / financial expenses  \
# net profit / total assets                                                                    0.019734
# current assets / short-term liabilities                                                     -0.000550
# [(cash + short-term securities + receivables - ...                                           0.000500
# sales / total assets                                                                         0.004898
# (gross profit + depreciation) / sales                                                       -0.000150
# (total liabilities * 365) / (gross profit + dep...                                          -0.001278
# sales (n) / sales (n-1)                                                                     -0.000420
# profit on operating activities / financial expe...                                           1.000000
# working capital / fixed assets                                                               0.001696
# logarithm of total assets                                                                   -0.012358
# (current liabilities * 365) / cost of products ...                                          -0.000776
# (current assets - inventories) / long-term liab...                                          -0.000556
# total liabilities / ((profit on operating activ...                                          -0.000358
# net profit / inventory                                                                      -0.000183
# working capital                                                                             -0.002228
# (current assets - inventory - short-term liabil...                                           0.001049
# sales / receivables                                                                          0.004992
# bankrupt                                                                                    -0.005265
#
#                                                     working capital / fixed assets  \
# net profit / total assets                                                 0.020467
# current assets / short-term liabilities                                   0.021738
# [(cash + short-term securities + receivables - ...                        0.000826
# sales / total assets                                                      0.004142
# (gross profit + depreciation) / sales                                    -0.000171
# (total liabilities * 365) / (gross profit + dep...                        0.000909
# sales (n) / sales (n-1)                                                  -0.000739
# profit on operating activities / financial expe...                        0.001696
# working capital / fixed assets                                            1.000000
# logarithm of total assets                                                -0.047753
# (current liabilities * 365) / cost of products ...                       -0.000096
# (current assets - inventories) / long-term liab...                       -0.000755
# total liabilities / ((profit on operating activ...                       -0.000630
# net profit / inventory                                                    0.001321
# working capital                                                          -0.000620
# (current assets - inventory - short-term liabil...                        0.001291
# sales / receivables                                                      -0.003662
# bankrupt                                                                 -0.004215
#
#                                                     logarithm of total assets  \
# net profit / total assets                                            0.023342
# current assets / short-term liabilities                             -0.020382
# [(cash + short-term securities + receivables - ...                  -0.000292
# sales / total assets                                                -0.076267
# (gross profit + depreciation) / sales                               -0.043398
# (total liabilities * 365) / (gross profit + dep...                  -0.023823
# sales (n) / sales (n-1)                                              0.023338
# profit on operating activities / financial expe...                  -0.012358
# working capital / fixed assets                                      -0.047753
# logarithm of total assets                                            1.000000
# (current liabilities * 365) / cost of products ...                  -0.018824
# (current assets - inventories) / long-term liab...                   0.060240
# total liabilities / ((profit on operating activ...                   0.005880
# net profit / inventory                                              -0.006506
# working capital                                                      0.193537
# (current assets - inventory - short-term liabil...                  -0.009946
# sales / receivables                                                 -0.088639
# bankrupt                                                            -0.031104
#
#                                                     (current liabilities * 365) / cost of products sold  \
# net profit / total assets                                                                    0.020267
# current assets / short-term liabilities                                                     -0.000276
# [(cash + short-term securities + receivables - ...                                          -0.000258
# sales / total assets                                                                         0.002045
# (gross profit + depreciation) / sales                                                        0.000718
# (total liabilities * 365) / (gross profit + dep...                                          -0.000443
# sales (n) / sales (n-1)                                                                     -0.000116
# profit on operating activities / financial expe...                                          -0.000776
# working capital / fixed assets                                                              -0.000096
# logarithm of total assets                                                                   -0.018824
# (current liabilities * 365) / cost of products ...                                           1.000000
# (current assets - inventories) / long-term liab...                                          -0.000678
# total liabilities / ((profit on operating activ...                                          -0.000182
# net profit / inventory                                                                      -0.000147
# working capital                                                                             -0.001875
# (current assets - inventory - short-term liabil...                                           0.000220
# sales / receivables                                                                         -0.000418
# bankrupt                                                                                    -0.000363
#
#                                                     (current assets - inventories) / long-term liabilities  \
# net profit / total assets                                                                    0.005553
# current assets / short-term liabilities                                                      0.001271
# [(cash + short-term securities + receivables - ...                                           0.000622
# sales / total assets                                                                        -0.002945
# (gross profit + depreciation) / sales                                                       -0.000463
# (total liabilities * 365) / (gross profit + dep...                                          -0.001469
# sales (n) / sales (n-1)                                                                     -0.000661
# profit on operating activities / financial expe...                                          -0.000556
# working capital / fixed assets                                                              -0.000755
# logarithm of total assets                                                                    0.060240
# (current liabilities * 365) / cost of products ...                                          -0.000678
# (current assets - inventories) / long-term liab...                                           1.000000
# total liabilities / ((profit on operating activ...                                          -0.000561
# net profit / inventory                                                                       0.000237
# working capital                                                                              0.101083
# (current assets - inventory - short-term liabil...                                           0.000695
# sales / receivables                                                                         -0.005142
# bankrupt                                                                                     0.003650
#
#                                                     total liabilities / ((profit on operating activities + depreciation) * (12/365))  \
# net profit / total assets                                                                    0.001714
# current assets / short-term liabilities                                                     -0.000165
# [(cash + short-term securities + receivables - ...                                           0.000123
# sales / total assets                                                                        -0.000485
# (gross profit + depreciation) / sales                                                        0.000261
# (total liabilities * 365) / (gross profit + dep...                                          -0.002262
# sales (n) / sales (n-1)                                                                     -0.000112
# profit on operating activities / financial expe...                                          -0.000358
# working capital / fixed assets                                                              -0.000630
# logarithm of total assets                                                                    0.005880
# (current liabilities * 365) / cost of products ...                                          -0.000182
# (current assets - inventories) / long-term liab...                                          -0.000561
# total liabilities / ((profit on operating activ...                                           1.000000
# net profit / inventory                                                                      -0.000103
# working capital                                                                             -0.000613
# (current assets - inventory - short-term liabil...                                           0.000248
# sales / receivables                                                                         -0.000704
# bankrupt                                                                                    -0.002262
#
#                                                     net profit / inventory  \
# net profit / total assets                                         0.009620
# current assets / short-term liabilities                           0.038634
# [(cash + short-term securities + receivables - ...                0.000270
# sales / total assets                                              0.016209
# (gross profit + depreciation) / sales                             0.000498
# (total liabilities * 365) / (gross profit + dep...                0.000002
# sales (n) / sales (n-1)                                          -0.000107
# profit on operating activities / financial expe...               -0.000183
# working capital / fixed assets                                    0.001321
# logarithm of total assets                                        -0.006506
# (current liabilities * 365) / cost of products ...               -0.000147
# (current assets - inventories) / long-term liab...                0.000237
# total liabilities / ((profit on operating activ...               -0.000103
# net profit / inventory                                            1.000000
# working capital                                                   0.001586
# (current assets - inventory - short-term liabil...                0.032610
# sales / receivables                                              -0.000605
# bankrupt                                                         -0.002242
#
#                                                     working capital  \
# net profit / total assets                                  0.012158
# current assets / short-term liabilities                   -0.000513
# [(cash + short-term securities + receivables - ...         0.001235
# sales / total assets                                      -0.008492
# (gross profit + depreciation) / sales                     -0.000663
# (total liabilities * 365) / (gross profit + dep...        -0.001293
# sales (n) / sales (n-1)                                   -0.011104
# profit on operating activities / financial expe...        -0.002228
# working capital / fixed assets                            -0.000620
# logarithm of total assets                                  0.193537
# (current liabilities * 365) / cost of products ...        -0.001875
# (current assets - inventories) / long-term liab...         0.101083
# total liabilities / ((profit on operating activ...        -0.000613
# net profit / inventory                                     0.001586
# working capital                                            1.000000
# (current assets - inventory - short-term liabil...         0.002395
# sales / receivables                                       -0.008466
# bankrupt                                                  -0.019179
#
#                                                     (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)  \
# net profit / total assets                                                                    0.048661
# current assets / short-term liabilities                                                      0.000051
# [(cash + short-term securities + receivables - ...                                           0.000003
# sales / total assets                                                                         0.002789
# (gross profit + depreciation) / sales                                                        0.001087
# (total liabilities * 365) / (gross profit + dep...                                           0.000645
# sales (n) / sales (n-1)                                                                     -0.000309
# profit on operating activities / financial expe...                                           0.001049
# working capital / fixed assets                                                               0.001291
# logarithm of total assets                                                                   -0.009946
# (current liabilities * 365) / cost of products ...                                           0.000220
# (current assets - inventories) / long-term liab...                                           0.000695
# total liabilities / ((profit on operating activ...                                           0.000248
# net profit / inventory                                                                       0.032610
# working capital                                                                              0.002395
# (current assets - inventory - short-term liabil...                                           1.000000
# sales / receivables                                                                          0.002047
# bankrupt                                                                                    -0.009320
#
#                                                     sales / receivables  \
# net profit / total assets                                     -0.035938
# current assets / short-term liabilities                       -0.000548
# [(cash + short-term securities + receivables - ...            -0.000430
# sales / total assets                                           0.059324
# (gross profit + depreciation) / sales                         -0.000645
# (total liabilities * 365) / (gross profit + dep...            -0.002593
# sales (n) / sales (n-1)                                       -0.001582
# profit on operating activities / financial expe...             0.004992
# working capital / fixed assets                                -0.003662
# logarithm of total assets                                     -0.088639
# (current liabilities * 365) / cost of products ...            -0.000418
# (current assets - inventories) / long-term liab...            -0.005142
# total liabilities / ((profit on operating activ...            -0.000704
# net profit / inventory                                        -0.000605
# working capital                                               -0.008466
# (current assets - inventory - short-term liabil...             0.002047
# sales / receivables                                            1.000000
# bankrupt                                                      -0.005393
#
#                                                     bankrupt
# net profit / total assets                          -0.027089
# current assets / short-term liabilities            -0.002071
# [(cash + short-term securities + receivables - ...  0.002381
# sales / total assets                               -0.001275
# (gross profit + depreciation) / sales              -0.001432
# (total liabilities * 365) / (gross profit + dep...  0.004495
# sales (n) / sales (n-1)                            -0.002301
# profit on operating activities / financial expe... -0.005265
# working capital / fixed assets                     -0.004215
# logarithm of total assets                          -0.031104
# (current liabilities * 365) / cost of products ... -0.000363
# (current assets - inventories) / long-term liab...  0.003650
# total liabilities / ((profit on operating activ... -0.002262
# net profit / inventory                             -0.002242
# working capital                                    -0.019179
# (current assets - inventory - short-term liabil... -0.009320
# sales / receivables                                -0.005393
# bankrupt                                            1.000000

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams.update({'font.size': 15})
fig, ax = plt.subplots(1, 1, figsize=(20,15))
sns.heatmap(correlation2, vmin=-1, vmax=1, annot=True, ax=ax, cmap=plt.cm.Greens)
plt.show()

# %% [markdown]
# ## Simplifying columns name

# %%
df_clean.to_csv("../Analyse_Exploratoire/data_without_correlation.csv", index = False)
